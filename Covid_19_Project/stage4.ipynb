# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
import seaborn as sns

# %%
df = pd.read_csv("Per_100,000Daily.csv")

# %%
assignments = pd.read_csv("CA.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Wave 3_Patients Admitted Due to COVID',
#        'Wave 3_Patients Admitted Not Due to COVID',
#        'Wave 3_Patients Newly Admitted', 'Wave 3_Patients Discharged',
#        'Wave 3_Patients Currently in ICU',
#        'Wave 3_Patients Currently ICU Intubated', 'Wave 3_Patients Expired'],
#       dtype='object')

# %%
assignments.columns
# Out:
# Index(['Unnamed: 0', 'cluster'], dtype='object')

# %%
assdf = df.merge(assignments, left_on="Unnamed: 0", right_on='Unnamed: 0')

# %%
#U.S. Census Bureau. (2021). INCOME IN THE PAST 12 MONTHS (IN 2021 INFLATION-ADJUSTED DOLLARS). American Community Survey, ACS 5-Year Estimates Subject Tables, Table S1901. Retrieved April 1, 2025, from https://data.census.gov/table/ACSST5Y2021.S1901?t=Income+and+Poverty&g=040XX00US36$0500000&y=2021&tp=true.
Income = pd.read_csv("ACSST5Y2021.S1901-2025-04-02T010000.csv")
#U.S. Census Bureau. "EDUCATIONAL ATTAINMENT." American Community Survey, ACS 5-Year Estimates Subject Tables, Table S1501, 2021, https://data.census.gov/table/ACSST5Y2021.S1501?t=Education:Educational+Attainment&g=040XX00US36$0500000&y=2021&tp=true. Accessed on April 1, 2025.
education = pd.read_csv("ACSST5Y2021.S1501-2025-04-02T010231.csv")
#U.S. Census Bureau. (2021). OCCUPATION BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER. American Community Survey, ACS 5-Year Estimates Subject Tables, Table S2406. Retrieved April 1, 2025, from https://data.census.gov/table/ACSST5Y2021.S2406?t=Class+of+Worker:Employment:Employment+and+Labor+Force+Status:Occupation&g=040XX00US36$0500000&y=2021&tp=true.
workerclass = pd.read_csv("ACSST5Y2021.S2406-2025-04-02T010549.csv")
#U.S. Census Bureau. (2021). COMPARATIVE ECONOMIC CHARACTERISTICS. American Community Survey, ACS 5-Year Estimates Comparison Profiles, Table CP03. Retrieved April 1, 2025, from https://data.census.gov/table/ACSCP5Y2021.CP03?t=Class+of+Worker:Employment:Employment+and+Labor+Force+Status:Occupation&g=040XX00US36$0500000&y=2021&tp=true.
unemployment = pd.read_csv("ACSCP5Y2021.CP03-2025-04-02T010708.csv")

# %%
def bestfunction(newstring):
    templist = newstring.split(",")
    if len(templist) == 2:
        tempstring = templist[0] + templist[1]
        newstring = int(tempstring)
    elif len(templist) == 3:
        tempstring = templist[0] + templist[1] + templist[2]
        newstring = int(tempstring)
    else:
        newstring = int(newstring)
    return newstring

# %%
newdf = pd.DataFrame(columns=["County","Median Income"])

# %%
bestlist = []
u = 1
for x in range(0,806):
    if u == 1:
        bestlist.append(Income.iloc[x,0])
        u = u + 1
    elif u == 3:
        bestlist.append(bestfunction(Income.iloc[x,12]))
        u = u + 1
    elif u == 13:
        newdf.loc[len(newdf)] = [bestlist[0], bestlist[1]]
        bestlist = []
        u = 1

    else:
        u = u + 1

# %%
df1list = df["Unnamed: 0"].unique()

# %%
for index,row in newdf.iterrows():
    newstring = newdf.iloc[index,0]
    wordlist = newstring.split(" ")
    if len(wordlist) > 4:
        beststring = wordlist[0] +  " " + wordlist[1]
        newdf.iloc[index,0] = beststring.upper()
    else:
        newdf.iloc[index,0] = wordlist[0].upper()

# %%
df2list = newdf["County"].unique()

# %%
for x in df1list:
    if x in df2list:
        pass
    else:
        print(x)

# %%
assdf = assdf.merge(newdf, left_on="Unnamed: 0", right_on="County")
assdf = assdf.drop(columns="County")

# %%
newdf = pd.DataFrame(columns=["County","Less than high school","High school graduate","Some college or associate's degree","Bachelor's degree or higher"])

# %%
bestlist = []
u = 1
for x in range(0,1178):
    if u == 1:
        bestlist.append(education.iloc[x,0])
        u = u + 1
    elif u == 3:
        totalpop = bestfunction(education.iloc[x,2]) + bestfunction(education.iloc[x,7])
        lesspop = bestfunction(education.iloc[x,3]) + bestfunction(education.iloc[x,8]) + bestfunction(education.iloc[x,9])
        highpop = bestfunction(education.iloc[x,4]) + bestfunction(education.iloc[x,10])
        somepop = bestfunction(education.iloc[x,5]) + bestfunction(education.iloc[x,11]) + bestfunction(education.iloc[x,12])
        higherpop = bestfunction(education.iloc[x,6]) + bestfunction(education.iloc[x,13]) + bestfunction(education.iloc[x,14])
        bestlist.append(lesspop/totalpop)
        bestlist.append(highpop/totalpop)
        bestlist.append(somepop/totalpop)
        bestlist.append(higherpop/totalpop)
        if bestlist[0] in ['Kings County, New York','New York County, New York','Queens County, New York']:
            print(totalpop)
            print(lesspop)
            print(highpop)
            print(somepop)
            print(higherpop)
        u = u + 1
    elif u == 19:
        newdf.loc[len(newdf)] = [bestlist[0], bestlist[1],bestlist[2],bestlist[3],bestlist[4]]
        bestlist = []
        u = 1
    else:
        u = u + 1
# Out:
# 2090262
# 332551
# 532622
# 441078
# 784011
# 1427229
# 159341
# 186076
# 230721
# 851091
# 1908997
# 319034
# 507104
# 463991
# 618868

# %%
for index,row in newdf.iterrows():
    newstring = newdf.iloc[index,0]
    wordlist = newstring.split(" ")
    if len(wordlist) > 4:
        beststring = wordlist[0] +  " " + wordlist[1]
        newdf.iloc[index,0] = beststring.upper()
    else:
        newdf.iloc[index,0] = wordlist[0].upper()

# %%
assdf = assdf.merge(newdf, left_on="Unnamed: 0", right_on="County")
assdf = assdf.drop(columns="County")

# %%
newdf = pd.DataFrame(columns=["County","Management, business, science, and arts occupations","Service occupations","Sales and office occupations","Natural resources, construction, and maintenance occupations","Production, transportation, and material moving occupations"])

# %%
bestlist = []
u = 1
for x in range(0,1178):
    if u == 1:
        bestlist.append(workerclass.iloc[x,0])
        u = u + 1
    elif u == 3:
        totalpop = bestfunction(workerclass.iloc[x,1])
        lesspop = bestfunction(workerclass.iloc[x,2])
        highpop = bestfunction(workerclass.iloc[x,3])
        somepop = bestfunction(workerclass.iloc[x,4])
        higherpop = bestfunction(workerclass.iloc[x,5])
        temppop = bestfunction(workerclass.iloc[x,6])
        bestlist.append(lesspop/totalpop)
        bestlist.append(highpop/totalpop)
        bestlist.append(somepop/totalpop)
        bestlist.append(higherpop/totalpop)
        bestlist.append(temppop/totalpop)
        u = u + 1
    elif u == 19:
        newdf.loc[len(newdf)] = [bestlist[0], bestlist[1],bestlist[2],bestlist[3],bestlist[4],bestlist[5]]
        bestlist = []
        u = 1
    else:
        u = u + 1

# %%
for index,row in newdf.iterrows():
    newstring = newdf.iloc[index,0]
    wordlist = newstring.split(" ")
    if len(wordlist) > 4:
        beststring = wordlist[0] +  " " + wordlist[1]
        newdf.iloc[index,0] = beststring.upper()
    else:
        newdf.iloc[index,0] = wordlist[0].upper()

# %%
assdf = assdf.merge(newdf, left_on="Unnamed: 0", right_on="County")
assdf = assdf.drop(columns="County")

# %%
newdf = pd.DataFrame(columns=["County","Unemployed","POVERTY"])

# %%
def secondbestfunction(newstring):
    newstring = newstring.replace("%","")
    newstring = float(newstring)
    return newstring

# %%
bestlist = []
u = 1
for x in range(0,248):
    if u == 1:
        bestlist.append(unemployment.iloc[x,0])
        u = u + 1
    elif u == 2:
        totalpop = secondbestfunction(unemployment.iloc[x,6])
        lesspop = secondbestfunction(unemployment.iloc[x,10])
        bestlist.append(totalpop)
        bestlist.append(lesspop)
        u = u + 1
    elif u == 4:
        newdf.loc[len(newdf)] = [bestlist[0], bestlist[1],bestlist[2]]
        bestlist = []
        u = 1
    else:
        u = u + 1

# %%
for index,row in newdf.iterrows():
    newstring = newdf.iloc[index,0]
    wordlist = newstring.split(" ")
    if len(wordlist) > 4:
        beststring = wordlist[0] +  " " + wordlist[1]
        newdf.iloc[index,0] = beststring.upper()
    else:
        newdf.iloc[index,0] = wordlist[0].upper()

# %%
assdf = assdf.merge(newdf, left_on="Unnamed: 0", right_on="County")
assdf = assdf.drop(columns="County")

# %%
df1 = assdf[assdf["cluster"] == 1]
df2 = assdf[assdf["cluster"] == 2]
df3 = assdf[assdf["cluster"] == 3]

# %%
#linear regresion
#decision trees
#random forest

# %%
from scipy.stats import pearsonr

# %%
testlist = ['Wave 3_Patients Admitted Due to COVID',
       'Wave 3_Patients Admitted Not Due to COVID',
       'Wave 3_Patients Newly Admitted', 'Wave 3_Patients Discharged',
       'Wave 3_Patients Currently in ICU',
       'Wave 3_Patients Currently ICU Intubated', 'Wave 3_Patients Expired']

# %%
trainlist = ['Median Income', 'Less than high school',
       'High school graduate', "Some college or associate's degree",
       "Bachelor's degree or higher",
       'Management, business, science, and arts occupations',
       'Service occupations', 'Sales and office occupations',
       'Natural resources, construction, and maintenance occupations',
       'Production, transportation, and material moving occupations',
       'Unemployed', 'POVERTY']

# %%
for x in testlist:
    print(x)
    print("")
    for y in trainlist:
        correlation_coefficient, p_value = pearsonr(df1[x], df1[y])

        print(f"Pearson correlation coefficient: {correlation_coefficient}")
        print(f"P-value: {p_value}")

        # Interpret the p-value
        alpha = 0.10  # Significance level
        if p_value < alpha:
            print(f"The correlation for {x} & {y} is statistically significant.")
            print(1)
        else:
            print(f"The correlation for {x} & {y} is not statistically significant.")
# Out:
# Wave 3_Patients Admitted Due to COVID
#
# Pearson correlation coefficient: 0.35272981428597144
# P-value: 0.23715808776899644
# The correlation for Wave 3_Patients Admitted Due to COVID & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.49914354686305834
# P-value: 0.08247289024188295
# The correlation for Wave 3_Patients Admitted Due to COVID & Less than high school is statistically significant.
# 1
# Pearson correlation coefficient: -0.37628577777006544
# P-value: 0.20507500550902488
# The correlation for Wave 3_Patients Admitted Due to COVID & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.3253679464825892
# P-value: 0.2780143603525807
# The correlation for Wave 3_Patients Admitted Due to COVID & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.3056299871942433
# P-value: 0.30986782197805635
# The correlation for Wave 3_Patients Admitted Due to COVID & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.4114730828393789
# P-value: 0.16244036150427665
# The correlation for Wave 3_Patients Admitted Due to COVID & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.003700347862980919
# P-value: 0.9904277689652371
# The correlation for Wave 3_Patients Admitted Due to COVID & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.1606687203232837
# P-value: 0.6000306362404165
# The correlation for Wave 3_Patients Admitted Due to COVID & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.4797814611803473
# P-value: 0.09708072714082784
# The correlation for Wave 3_Patients Admitted Due to COVID & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.3861932235610984
# P-value: 0.19243326490335527
# The correlation for Wave 3_Patients Admitted Due to COVID & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.0763278499233161
# P-value: 0.8042625320850274
# The correlation for Wave 3_Patients Admitted Due to COVID & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.16280334170114935
# P-value: 0.5951294981658564
# The correlation for Wave 3_Patients Admitted Due to COVID & POVERTY is not statistically significant.
# Wave 3_Patients Admitted Not Due to COVID
#
# Pearson correlation coefficient: 0.3486696296038799
# P-value: 0.24297704369837317
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.03851669131106361
# P-value: 0.9005825761246392
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.4027271137271381
# P-value: 0.17245123521409308
# The correlation for Wave 3_Patients Admitted Not Due to COVID & High school graduate is not statistically significant.
# Pearson correlation coefficient: -0.4164085357272405
# P-value: 0.1569602942542796
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.42515948037615
# P-value: 0.14754137955073146
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.29871143432010283
# P-value: 0.3215002207556668
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: 0.020727996129013784
# P-value: 0.9464133013553753
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.17737692165090813
# P-value: 0.5620968265890247
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.06892226336098098
# P-value: 0.8229691461053936
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: -0.34832017956791805
# P-value: 0.24348184061858752
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.46542708775926467
# P-value: 0.10898792382703511
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.5108023024733135
# P-value: 0.07445273837551268
# The correlation for Wave 3_Patients Admitted Not Due to COVID & POVERTY is statistically significant.
# 1
# Wave 3_Patients Newly Admitted
#
# Pearson correlation coefficient: 0.42696566379717726
# P-value: 0.145644429791592
# The correlation for Wave 3_Patients Newly Admitted & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.17468566152351744
# P-value: 0.5681393376657632
# The correlation for Wave 3_Patients Newly Admitted & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.5011931942102793
# P-value: 0.08102145812135646
# The correlation for Wave 3_Patients Newly Admitted & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: 0.2064606927666361
# P-value: 0.49856621326435047
# The correlation for Wave 3_Patients Newly Admitted & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.3303822176565298
# P-value: 0.27023902523314464
# The correlation for Wave 3_Patients Newly Admitted & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.4664992981741902
# P-value: 0.10806602355846937
# The correlation for Wave 3_Patients Newly Admitted & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.21453882153026774
# P-value: 0.48152465967085256
# The correlation for Wave 3_Patients Newly Admitted & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.006653057683555168
# P-value: 0.982790351773597
# The correlation for Wave 3_Patients Newly Admitted & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.42600172553386034
# P-value: 0.14665481150648527
# The correlation for Wave 3_Patients Newly Admitted & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: -0.3322600795809498
# P-value: 0.2673603346214804
# The correlation for Wave 3_Patients Newly Admitted & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.010486079017721264
# P-value: 0.9728780421892985
# The correlation for Wave 3_Patients Newly Admitted & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.14388263188766198
# P-value: 0.6391002887914158
# The correlation for Wave 3_Patients Newly Admitted & POVERTY is not statistically significant.
# Wave 3_Patients Discharged
#
# Pearson correlation coefficient: -0.14787889496766418
# P-value: 0.6297162012541989
# The correlation for Wave 3_Patients Discharged & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.08273788048172032
# P-value: 0.7881474729765523
# The correlation for Wave 3_Patients Discharged & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.27413268224610426
# P-value: 0.36475272585471574
# The correlation for Wave 3_Patients Discharged & High school graduate is not statistically significant.
# Pearson correlation coefficient: -0.26685581326855307
# P-value: 0.37812564868337656
# The correlation for Wave 3_Patients Discharged & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.07520544664723347
# P-value: 0.8070918188710088
# The correlation for Wave 3_Patients Discharged & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: -0.07285169569733917
# P-value: 0.8130319983895938
# The correlation for Wave 3_Patients Discharged & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: 0.16033379733506653
# P-value: 0.6008010428037487
# The correlation for Wave 3_Patients Discharged & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.25517714390171337
# P-value: 0.40011746435149936
# The correlation for Wave 3_Patients Discharged & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.15974474170233852
# P-value: 0.6021569449135501
# The correlation for Wave 3_Patients Discharged & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.1969093743284574
# P-value: 0.5190624500178881
# The correlation for Wave 3_Patients Discharged & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.12715846834418715
# P-value: 0.6788979126945345
# The correlation for Wave 3_Patients Discharged & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.06747310717844696
# P-value: 0.8266401409890349
# The correlation for Wave 3_Patients Discharged & POVERTY is not statistically significant.
# Wave 3_Patients Currently in ICU
#
# Pearson correlation coefficient: 0.5558479658074145
# P-value: 0.04856028617517319
# The correlation for Wave 3_Patients Currently in ICU & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: -0.3205119982161606
# P-value: 0.2856669020968348
# The correlation for Wave 3_Patients Currently in ICU & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.39283118924374855
# P-value: 0.18424402199356704
# The correlation for Wave 3_Patients Currently in ICU & High school graduate is not statistically significant.
# Pearson correlation coefficient: -0.0879010783004243
# P-value: 0.7752229125627687
# The correlation for Wave 3_Patients Currently in ICU & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.39752594519178125
# P-value: 0.1785874909424475
# The correlation for Wave 3_Patients Currently in ICU & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.4727721793122927
# P-value: 0.10277813294576447
# The correlation for Wave 3_Patients Currently in ICU & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.5236434047628891
# P-value: 0.06626768981629204
# The correlation for Wave 3_Patients Currently in ICU & Service occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.2757432844959326
# P-value: 0.3618275188118323
# The correlation for Wave 3_Patients Currently in ICU & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.5584372847166577
# P-value: 0.04730242207432649
# The correlation for Wave 3_Patients Currently in ICU & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.19522831281427633
# P-value: 0.52270789433896
# The correlation for Wave 3_Patients Currently in ICU & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: 0.3551332718467023
# P-value: 0.23375357789201578
# The correlation for Wave 3_Patients Currently in ICU & Unemployed is not statistically significant.
# Pearson correlation coefficient: 0.143495645337713
# P-value: 0.6400116759615986
# The correlation for Wave 3_Patients Currently in ICU & POVERTY is not statistically significant.
# Wave 3_Patients Currently ICU Intubated
#
# Pearson correlation coefficient: 0.6915781270140968
# P-value: 0.008830876744501165
# The correlation for Wave 3_Patients Currently ICU Intubated & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: -0.47511878268948693
# P-value: 0.10084605248108806
# The correlation for Wave 3_Patients Currently ICU Intubated & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.546876999461273
# P-value: 0.053103858419755914
# The correlation for Wave 3_Patients Currently ICU Intubated & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: -0.1655892440673319
# P-value: 0.588756678092931
# The correlation for Wave 3_Patients Currently ICU Intubated & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.5765152408987868
# P-value: 0.03916362044688289
# The correlation for Wave 3_Patients Currently ICU Intubated & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: 0.6108315473370556
# P-value: 0.026578809162658836
# The correlation for Wave 3_Patients Currently ICU Intubated & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.4954060007777731
# P-value: 0.08516575696336236
# The correlation for Wave 3_Patients Currently ICU Intubated & Service occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.3317571439235263
# P-value: 0.2681295403206679
# The correlation for Wave 3_Patients Currently ICU Intubated & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.6121314391005928
# P-value: 0.02616996784607412
# The correlation for Wave 3_Patients Currently ICU Intubated & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.4008583018216446
# P-value: 0.17464028235136134
# The correlation for Wave 3_Patients Currently ICU Intubated & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: 0.293493484920114
# P-value: 0.3304321923326226
# The correlation for Wave 3_Patients Currently ICU Intubated & Unemployed is not statistically significant.
# Pearson correlation coefficient: 0.06452290869635505
# P-value: 0.8341235291796533
# The correlation for Wave 3_Patients Currently ICU Intubated & POVERTY is not statistically significant.
# Wave 3_Patients Expired
#
# Pearson correlation coefficient: 0.414337665852983
# P-value: 0.15924487508281113
# The correlation for Wave 3_Patients Expired & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.11767631453143618
# P-value: 0.7018152433714152
# The correlation for Wave 3_Patients Expired & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.5860337546771021
# P-value: 0.03531219894210342
# The correlation for Wave 3_Patients Expired & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: 0.08873467737334524
# P-value: 0.7731411410442165
# The correlation for Wave 3_Patients Expired & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.4097098599048016
# P-value: 0.164427675691003
# The correlation for Wave 3_Patients Expired & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.5128810590752066
# P-value: 0.07308221597333255
# The correlation for Wave 3_Patients Expired & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.3474386425257323
# P-value: 0.24475806013531157
# The correlation for Wave 3_Patients Expired & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.02115051117341274
# P-value: 0.9453224523980229
# The correlation for Wave 3_Patients Expired & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.321433502083176
# P-value: 0.28420542689868333
# The correlation for Wave 3_Patients Expired & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: -0.3782063970367796
# P-value: 0.20258501903867274
# The correlation for Wave 3_Patients Expired & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.06239771274094384
# P-value: 0.8395222569808829
# The correlation for Wave 3_Patients Expired & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.2280840855723938
# P-value: 0.4535733026561633
# The correlation for Wave 3_Patients Expired & POVERTY is not statistically significant.

# %%
for x in testlist:
    print(x)
    print("")
    for y in trainlist:
        correlation_coefficient, p_value = pearsonr(df2[x], df2[y])

        print(f"Pearson correlation coefficient: {correlation_coefficient}")
        print(f"P-value: {p_value}")

        # Interpret the p-value
        alpha = 0.10  # Significance level
        if p_value < alpha:
            print(f"The correlation for {x} & {y} is statistically significant.")
            print(1)
        else:
            print(f"The correlation for {x} & {y} is not statistically significant.")
# Out:
# Wave 3_Patients Admitted Due to COVID
#
# Pearson correlation coefficient: 0.08180809145826934
# P-value: 0.7316924690861287
# The correlation for Wave 3_Patients Admitted Due to COVID & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.4508788927948958
# P-value: 0.0460180073260142
# The correlation for Wave 3_Patients Admitted Due to COVID & Less than high school is statistically significant.
# 1
# Pearson correlation coefficient: -0.32031504311174447
# P-value: 0.16855697447893292
# The correlation for Wave 3_Patients Admitted Due to COVID & High school graduate is not statistically significant.
# Pearson correlation coefficient: -0.09870295907919172
# P-value: 0.6788710119736883
# The correlation for Wave 3_Patients Admitted Due to COVID & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.39682245313225994
# P-value: 0.0832153459747203
# The correlation for Wave 3_Patients Admitted Due to COVID & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: 0.45275348815002303
# P-value: 0.045010702056634704
# The correlation for Wave 3_Patients Admitted Due to COVID & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.38386997717140414
# P-value: 0.09474024394994765
# The correlation for Wave 3_Patients Admitted Due to COVID & Service occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.07116132255174425
# P-value: 0.7656042596191126
# The correlation for Wave 3_Patients Admitted Due to COVID & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.2914658826195354
# P-value: 0.21245823722570722
# The correlation for Wave 3_Patients Admitted Due to COVID & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: -0.3662221872665014
# P-value: 0.11226674869381865
# The correlation for Wave 3_Patients Admitted Due to COVID & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.32429458496920227
# P-value: 0.16303223708948422
# The correlation for Wave 3_Patients Admitted Due to COVID & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.38416625917281233
# P-value: 0.09446423030030016
# The correlation for Wave 3_Patients Admitted Due to COVID & POVERTY is statistically significant.
# 1
# Wave 3_Patients Admitted Not Due to COVID
#
# Pearson correlation coefficient: 0.17405448271299898
# P-value: 0.4630063914205642
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Median Income is not statistically significant.
# Pearson correlation coefficient: 0.09776863748550163
# P-value: 0.6817573845948168
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.4609266451674837
# P-value: 0.040815817546289324
# The correlation for Wave 3_Patients Admitted Not Due to COVID & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: -0.43501158141614743
# P-value: 0.05525332706503709
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Some college or associate's degree is statistically significant.
# 1
# Pearson correlation coefficient: 0.4208319518860054
# P-value: 0.06464284850085907
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: 0.4536507118396432
# P-value: 0.0445346308937387
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.09372208667326987
# P-value: 0.694307030124679
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.44011453727191624
# P-value: 0.052141633160871684
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Sales and office occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.6216534958918967
# P-value: 0.0034323320319782505
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.3415658453111263
# P-value: 0.14050160455432087
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: 0.0998824674659136
# P-value: 0.6752333325438392
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Unemployed is not statistically significant.
# Pearson correlation coefficient: 0.040477245545831146
# P-value: 0.8654562886278558
# The correlation for Wave 3_Patients Admitted Not Due to COVID & POVERTY is not statistically significant.
# Wave 3_Patients Newly Admitted
#
# Pearson correlation coefficient: -0.07170034549824048
# P-value: 0.7638769034150218
# The correlation for Wave 3_Patients Newly Admitted & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.34590526457164017
# P-value: 0.13520343271603086
# The correlation for Wave 3_Patients Newly Admitted & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.0461406490504043
# P-value: 0.8468314234690517
# The correlation for Wave 3_Patients Newly Admitted & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.24288493157477248
# P-value: 0.30215219223770984
# The correlation for Wave 3_Patients Newly Admitted & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.0028661936527490106
# P-value: 0.9904315067770217
# The correlation for Wave 3_Patients Newly Admitted & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.03015016956781992
# P-value: 0.8995880819807391
# The correlation for Wave 3_Patients Newly Admitted & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.28007091728522393
# P-value: 0.23170178058960494
# The correlation for Wave 3_Patients Newly Admitted & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.27343162548527217
# P-value: 0.24341896715960443
# The correlation for Wave 3_Patients Newly Admitted & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.14693725227750484
# P-value: 0.5364555345181854
# The correlation for Wave 3_Patients Newly Admitted & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.042512964114675
# P-value: 0.858753173959671
# The correlation for Wave 3_Patients Newly Admitted & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.3751668059831984
# P-value: 0.10311382176388101
# The correlation for Wave 3_Patients Newly Admitted & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.3932576964964572
# P-value: 0.08627794873354555
# The correlation for Wave 3_Patients Newly Admitted & POVERTY is statistically significant.
# 1
# Wave 3_Patients Discharged
#
# Pearson correlation coefficient: -0.26794410468175406
# P-value: 0.25338548161964886
# The correlation for Wave 3_Patients Discharged & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.381972997730737
# P-value: 0.09652145535272519
# The correlation for Wave 3_Patients Discharged & Less than high school is statistically significant.
# 1
# Pearson correlation coefficient: 0.04338558464289742
# P-value: 0.855882671699115
# The correlation for Wave 3_Patients Discharged & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.4003847316671184
# P-value: 0.08023596289615567
# The correlation for Wave 3_Patients Discharged & Some college or associate's degree is statistically significant.
# 1
# Pearson correlation coefficient: -0.054249898324369085
# P-value: 0.8203009584490015
# The correlation for Wave 3_Patients Discharged & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.05571567618325334
# P-value: 0.815524611787352
# The correlation for Wave 3_Patients Discharged & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.21905133841929209
# P-value: 0.353465444991906
# The correlation for Wave 3_Patients Discharged & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.1757998369483375
# P-value: 0.4584622013445073
# The correlation for Wave 3_Patients Discharged & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.08794662788038674
# P-value: 0.7123513290167849
# The correlation for Wave 3_Patients Discharged & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.09634102861187818
# P-value: 0.6861758754703172
# The correlation for Wave 3_Patients Discharged & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.25574536575023854
# P-value: 0.27645789469118864
# The correlation for Wave 3_Patients Discharged & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.2238919696659516
# P-value: 0.3426583209343722
# The correlation for Wave 3_Patients Discharged & POVERTY is not statistically significant.
# Wave 3_Patients Currently in ICU
#
# Pearson correlation coefficient: -0.32870982887824574
# P-value: 0.15705005395000457
# The correlation for Wave 3_Patients Currently in ICU & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.23057391308266353
# P-value: 0.3280617134579109
# The correlation for Wave 3_Patients Currently in ICU & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.05276193872063728
# P-value: 0.8251558230330808
# The correlation for Wave 3_Patients Currently in ICU & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.32623573812074724
# P-value: 0.1603831546858902
# The correlation for Wave 3_Patients Currently in ICU & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.08407872689675389
# P-value: 0.7245193377294539
# The correlation for Wave 3_Patients Currently in ICU & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.0603090916075948
# P-value: 0.8005978714551543
# The correlation for Wave 3_Patients Currently in ICU & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.2700975311821435
# P-value: 0.24944392502625945
# The correlation for Wave 3_Patients Currently in ICU & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.01967340330604518
# P-value: 0.9343886574698382
# The correlation for Wave 3_Patients Currently in ICU & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.1380925328793134
# P-value: 0.5615121746040435
# The correlation for Wave 3_Patients Currently in ICU & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.2533854856426544
# P-value: 0.28106746241535596
# The correlation for Wave 3_Patients Currently in ICU & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.2824298018808027
# P-value: 0.2276284682583887
# The correlation for Wave 3_Patients Currently in ICU & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.28174509985611607
# P-value: 0.22880597318889445
# The correlation for Wave 3_Patients Currently in ICU & POVERTY is not statistically significant.
# Wave 3_Patients Currently ICU Intubated
#
# Pearson correlation coefficient: -0.3335041383596694
# P-value: 0.15072832309438036
# The correlation for Wave 3_Patients Currently ICU Intubated & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.263697911518518
# P-value: 0.26127302327190705
# The correlation for Wave 3_Patients Currently ICU Intubated & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.1682252994789296
# P-value: 0.47834795033170957
# The correlation for Wave 3_Patients Currently ICU Intubated & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.2957964060515989
# P-value: 0.20543033225696278
# The correlation for Wave 3_Patients Currently ICU Intubated & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.12771617708662467
# P-value: 0.5915487667570363
# The correlation for Wave 3_Patients Currently ICU Intubated & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.016070494610800387
# P-value: 0.9463860575602764
# The correlation for Wave 3_Patients Currently ICU Intubated & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.3085059860328847
# P-value: 0.18570239508619996
# The correlation for Wave 3_Patients Currently ICU Intubated & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.13746102782650804
# P-value: 0.5633207579490812
# The correlation for Wave 3_Patients Currently ICU Intubated & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.008925873773630744
# P-value: 0.9702075639713041
# The correlation for Wave 3_Patients Currently ICU Intubated & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.35648958725531577
# P-value: 0.12287529522565266
# The correlation for Wave 3_Patients Currently ICU Intubated & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.23760047645917282
# P-value: 0.3131169492117041
# The correlation for Wave 3_Patients Currently ICU Intubated & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.22495160468646963
# P-value: 0.3403186383228046
# The correlation for Wave 3_Patients Currently ICU Intubated & POVERTY is not statistically significant.
# Wave 3_Patients Expired
#
# Pearson correlation coefficient: -0.5070387128119759
# P-value: 0.022503852092986224
# The correlation for Wave 3_Patients Expired & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: -0.22833319005596506
# P-value: 0.332914855087269
# The correlation for Wave 3_Patients Expired & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.5620877388720207
# P-value: 0.009895137421908751
# The correlation for Wave 3_Patients Expired & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: 0.5540976955780793
# P-value: 0.011242968496685504
# The correlation for Wave 3_Patients Expired & Some college or associate's degree is statistically significant.
# 1
# Pearson correlation coefficient: -0.48316914632749847
# P-value: 0.030920769951395755
# The correlation for Wave 3_Patients Expired & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: -0.3911227775245124
# P-value: 0.08815148190934911
# The correlation for Wave 3_Patients Expired & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.09301220032321975
# P-value: 0.69651664210679
# The correlation for Wave 3_Patients Expired & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.27220983449870817
# P-value: 0.24561588770724607
# The correlation for Wave 3_Patients Expired & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.3381308506061743
# P-value: 0.1447976778699563
# The correlation for Wave 3_Patients Expired & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.6446696410788877
# P-value: 0.002150741338626085
# The correlation for Wave 3_Patients Expired & Production, transportation, and material moving occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.39683305010226466
# P-value: 0.08320636335746806
# The correlation for Wave 3_Patients Expired & Unemployed is statistically significant.
# 1
# Pearson correlation coefficient: -0.29197614631631097
# P-value: 0.21162200502627784
# The correlation for Wave 3_Patients Expired & POVERTY is not statistically significant.

# %%
for x in testlist:
    print(x)
    print("")
    for y in trainlist:
        correlation_coefficient, p_value = pearsonr(df3[x], df3[y])

        print(f"Pearson correlation coefficient: {correlation_coefficient}")
        print(f"P-value: {p_value}")

        # Interpret the p-value
        alpha = 0.10  # Significance level
        if p_value < alpha:
            print(f"The correlation for {x} & {y} is statistically significant.")
            print(1)
        else:
            print(f"The correlation for {x} & {y} is not statistically significant.")
# Out:
# Wave 3_Patients Admitted Due to COVID
#
# Pearson correlation coefficient: 0.3133771213547917
# P-value: 0.13592783516731594
# The correlation for Wave 3_Patients Admitted Due to COVID & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.08202065337068057
# P-value: 0.7031958081450727
# The correlation for Wave 3_Patients Admitted Due to COVID & Less than high school is not statistically significant.
# Pearson correlation coefficient: -0.1323467068389953
# P-value: 0.5375822539892683
# The correlation for Wave 3_Patients Admitted Due to COVID & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.04189122270141274
# P-value: 0.8458991139080849
# The correlation for Wave 3_Patients Admitted Due to COVID & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: 0.11241396218022719
# P-value: 0.600990095092798
# The correlation for Wave 3_Patients Admitted Due to COVID & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: 0.03350465599994851
# P-value: 0.8764906300359809
# The correlation for Wave 3_Patients Admitted Due to COVID & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.19522776684108598
# P-value: 0.36061177008595513
# The correlation for Wave 3_Patients Admitted Due to COVID & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.12519164751433434
# P-value: 0.5599798694666462
# The correlation for Wave 3_Patients Admitted Due to COVID & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.1191297937154881
# P-value: 0.5792779581112248
# The correlation for Wave 3_Patients Admitted Due to COVID & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.056559347465639113
# P-value: 0.7929350130279581
# The correlation for Wave 3_Patients Admitted Due to COVID & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.03856743356510585
# P-value: 0.8579998892523268
# The correlation for Wave 3_Patients Admitted Due to COVID & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.25118705655938967
# P-value: 0.2364254893227794
# The correlation for Wave 3_Patients Admitted Due to COVID & POVERTY is not statistically significant.
# Wave 3_Patients Admitted Not Due to COVID
#
# Pearson correlation coefficient: 0.4060429980954884
# P-value: 0.04898026408751859
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: 0.4124151379533816
# P-value: 0.04520839510419035
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Less than high school is statistically significant.
# 1
# Pearson correlation coefficient: -0.45990683661024356
# P-value: 0.02374708880896785
# The correlation for Wave 3_Patients Admitted Not Due to COVID & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: -0.639828874612133
# P-value: 0.0007601411562562477
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Some college or associate's degree is statistically significant.
# 1
# Pearson correlation coefficient: 0.5764743461094852
# P-value: 0.0031925004411613557
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: 0.4242951544129192
# P-value: 0.03878686931176113
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.18161018355701383
# P-value: 0.3957119311917802
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.25430771935795476
# P-value: 0.2304582272349327
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: -0.5767206770464173
# P-value: 0.003176487187538964
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.5674563886317203
# P-value: 0.0038276615508563926
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Production, transportation, and material moving occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.34919991808876116
# P-value: 0.09442080286414178
# The correlation for Wave 3_Patients Admitted Not Due to COVID & Unemployed is statistically significant.
# 1
# Pearson correlation coefficient: 0.2898740235563513
# P-value: 0.16944468186502892
# The correlation for Wave 3_Patients Admitted Not Due to COVID & POVERTY is not statistically significant.
# Wave 3_Patients Newly Admitted
#
# Pearson correlation coefficient: -0.19913170951170545
# P-value: 0.35089556593125354
# The correlation for Wave 3_Patients Newly Admitted & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.05525125362009735
# P-value: 0.797625971001132
# The correlation for Wave 3_Patients Newly Admitted & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.3546149382815217
# P-value: 0.08907913727247765
# The correlation for Wave 3_Patients Newly Admitted & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: 0.12454700336507969
# P-value: 0.562018261324218
# The correlation for Wave 3_Patients Newly Admitted & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.3312427715870006
# P-value: 0.11384674417036444
# The correlation for Wave 3_Patients Newly Admitted & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: -0.18645985375023888
# P-value: 0.3829977743677261
# The correlation for Wave 3_Patients Newly Admitted & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: 0.2467735814644828
# P-value: 0.24503679822988286
# The correlation for Wave 3_Patients Newly Admitted & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.1870054239795068
# P-value: 0.3815822059712295
# The correlation for Wave 3_Patients Newly Admitted & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.25561779237909454
# P-value: 0.22798307559966244
# The correlation for Wave 3_Patients Newly Admitted & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.02818172382201989
# P-value: 0.8959991964803848
# The correlation for Wave 3_Patients Newly Admitted & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.13870502240087823
# P-value: 0.518037038017377
# The correlation for Wave 3_Patients Newly Admitted & Unemployed is not statistically significant.
# Pearson correlation coefficient: 0.00977923993123149
# P-value: 0.9638269936921948
# The correlation for Wave 3_Patients Newly Admitted & POVERTY is not statistically significant.
# Wave 3_Patients Discharged
#
# Pearson correlation coefficient: -0.37032528364339456
# P-value: 0.0748605621067641
# The correlation for Wave 3_Patients Discharged & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: -0.12135358159714778
# P-value: 0.5721648232063857
# The correlation for Wave 3_Patients Discharged & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.5235487409839943
# P-value: 0.008650503195812715
# The correlation for Wave 3_Patients Discharged & High school graduate is statistically significant.
# 1
# Pearson correlation coefficient: 0.15406258846016047
# P-value: 0.47228458742779533
# The correlation for Wave 3_Patients Discharged & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.4553902225005878
# P-value: 0.02534077394374248
# The correlation for Wave 3_Patients Discharged & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: -0.3052923711533925
# P-value: 0.1468696965712524
# The correlation for Wave 3_Patients Discharged & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: 0.15060192897080538
# P-value: 0.48240989023990133
# The correlation for Wave 3_Patients Discharged & Service occupations is not statistically significant.
# Pearson correlation coefficient: -0.219035014015679
# P-value: 0.3037993390786667
# The correlation for Wave 3_Patients Discharged & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.4222569455215866
# P-value: 0.03983410220086496
# The correlation for Wave 3_Patients Discharged & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.19842186675092616
# P-value: 0.35265065239896864
# The correlation for Wave 3_Patients Discharged & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.0024145517284056423
# P-value: 0.9910659987943764
# The correlation for Wave 3_Patients Discharged & Unemployed is not statistically significant.
# Pearson correlation coefficient: 0.16618730692742067
# P-value: 0.43768624216598484
# The correlation for Wave 3_Patients Discharged & POVERTY is not statistically significant.
# Wave 3_Patients Currently in ICU
#
# Pearson correlation coefficient: -0.38231158997472536
# P-value: 0.0652258017107018
# The correlation for Wave 3_Patients Currently in ICU & Median Income is statistically significant.
# 1
# Pearson correlation coefficient: -0.2518106600790675
# P-value: 0.23522500699478455
# The correlation for Wave 3_Patients Currently in ICU & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.2808933018971315
# P-value: 0.1836550480160257
# The correlation for Wave 3_Patients Currently in ICU & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.5577176299373396
# P-value: 0.00463016817872745
# The correlation for Wave 3_Patients Currently in ICU & Some college or associate's degree is statistically significant.
# 1
# Pearson correlation coefficient: -0.4511223472046129
# P-value: 0.026924645873233975
# The correlation for Wave 3_Patients Currently in ICU & Bachelor's degree or higher is statistically significant.
# 1
# Pearson correlation coefficient: -0.38893298918082386
# P-value: 0.06032789184250441
# The correlation for Wave 3_Patients Currently in ICU & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.114564777570441
# P-value: 0.5939994058106771
# The correlation for Wave 3_Patients Currently in ICU & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.11672286448550934
# P-value: 0.5870200817667933
# The correlation for Wave 3_Patients Currently in ICU & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.39569426617590925
# P-value: 0.055624005263206364
# The correlation for Wave 3_Patients Currently in ICU & Natural resources, construction, and maintenance occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.411328807028418
# P-value: 0.04583479746598701
# The correlation for Wave 3_Patients Currently in ICU & Production, transportation, and material moving occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.4631697293198266
# P-value: 0.022646842406827326
# The correlation for Wave 3_Patients Currently in ICU & Unemployed is statistically significant.
# 1
# Pearson correlation coefficient: -0.4268801819757304
# P-value: 0.03749008196313858
# The correlation for Wave 3_Patients Currently in ICU & POVERTY is statistically significant.
# 1
# Wave 3_Patients Currently ICU Intubated
#
# Pearson correlation coefficient: 0.08389643794167802
# P-value: 0.6967183028321539
# The correlation for Wave 3_Patients Currently ICU Intubated & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.15830428532115692
# P-value: 0.46002426806029106
# The correlation for Wave 3_Patients Currently ICU Intubated & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.0038863324641072727
# P-value: 0.9856207571449627
# The correlation for Wave 3_Patients Currently ICU Intubated & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.14736188696202457
# P-value: 0.4919881389152139
# The correlation for Wave 3_Patients Currently ICU Intubated & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.02691365933640852
# P-value: 0.9006557188424642
# The correlation for Wave 3_Patients Currently ICU Intubated & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: -0.10740446499304576
# P-value: 0.6174044009334514
# The correlation for Wave 3_Patients Currently ICU Intubated & Management, business, science, and arts occupations is not statistically significant.
# Pearson correlation coefficient: -0.29032760704162597
# P-value: 0.16874792943761688
# The correlation for Wave 3_Patients Currently ICU Intubated & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.36537674482316584
# P-value: 0.07913910566034663
# The correlation for Wave 3_Patients Currently ICU Intubated & Sales and office occupations is statistically significant.
# 1
# Pearson correlation coefficient: 0.1385195498205799
# P-value: 0.5186022912127696
# The correlation for Wave 3_Patients Currently ICU Intubated & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.1218637700785083
# P-value: 0.570538366573359
# The correlation for Wave 3_Patients Currently ICU Intubated & Production, transportation, and material moving occupations is not statistically significant.
# Pearson correlation coefficient: -0.19003517722400573
# P-value: 0.3737755207226109
# The correlation for Wave 3_Patients Currently ICU Intubated & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.2982393788698916
# P-value: 0.15691462349217522
# The correlation for Wave 3_Patients Currently ICU Intubated & POVERTY is not statistically significant.
# Wave 3_Patients Expired
#
# Pearson correlation coefficient: -0.20970378891474506
# P-value: 0.3253690468899175
# The correlation for Wave 3_Patients Expired & Median Income is not statistically significant.
# Pearson correlation coefficient: -0.034400300566808484
# P-value: 0.8732146289582592
# The correlation for Wave 3_Patients Expired & Less than high school is not statistically significant.
# Pearson correlation coefficient: 0.1924448055976437
# P-value: 0.36763285842148674
# The correlation for Wave 3_Patients Expired & High school graduate is not statistically significant.
# Pearson correlation coefficient: 0.29507071356182807
# P-value: 0.16158149176143496
# The correlation for Wave 3_Patients Expired & Some college or associate's degree is not statistically significant.
# Pearson correlation coefficient: -0.31289937096432624
# P-value: 0.1365576558556969
# The correlation for Wave 3_Patients Expired & Bachelor's degree or higher is not statistically significant.
# Pearson correlation coefficient: -0.34804786439641044
# P-value: 0.09558739276506617
# The correlation for Wave 3_Patients Expired & Management, business, science, and arts occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.18802013484006372
# P-value: 0.37895733224302164
# The correlation for Wave 3_Patients Expired & Service occupations is not statistically significant.
# Pearson correlation coefficient: 0.2926049901254935
# P-value: 0.16527983194098542
# The correlation for Wave 3_Patients Expired & Sales and office occupations is not statistically significant.
# Pearson correlation coefficient: 0.18223763234245913
# P-value: 0.39405376390442415
# The correlation for Wave 3_Patients Expired & Natural resources, construction, and maintenance occupations is not statistically significant.
# Pearson correlation coefficient: 0.48390104883558593
# P-value: 0.016579700421293198
# The correlation for Wave 3_Patients Expired & Production, transportation, and material moving occupations is statistically significant.
# 1
# Pearson correlation coefficient: -0.29140583635862005
# P-value: 0.1670996832204713
# The correlation for Wave 3_Patients Expired & Unemployed is not statistically significant.
# Pearson correlation coefficient: -0.32414695309979696
# P-value: 0.12227798060563902
# The correlation for Wave 3_Patients Expired & POVERTY is not statistically significant.

# %%
df1.to_csv("Cluster1FinalData.csv")
df2.to_csv("Cluster2FinalData.csv")
df3.to_csv("Cluster3FinalData.csv")

# %%
from scipy.stats import anderson

# %%
def get_range(data):
  return max(data) - min(data)

# %%
def testfunc(testthing,data,yesgraph=True):
    if yesgraph == True:
        plt.hist(data[testthing], bins=7)
        plt.show()
    result = anderson(data[testthing])
    print('Test Statistic:', result.statistic)
    print('Critical Values:', result.critical_values)
    print('Significance Levels:', result.significance_level)
    for i in range(len(result.critical_values)):
        sl, cv = result.significance_level[i], result.critical_values[i]
        if result.statistic < cv:
            print('Data looks {} normal (significance level {}%)'.format('likely' if sl > 5 else 'very likely', sl))
        else:
            print('Data does not look normal (significance level {}%)'.format(sl))
    print(f"Mean: {data[testthing].mean()}")
    print(f"Median: {data[testthing].median()}")
    print(f"Range: {get_range(data[testthing])}")

# %%
dataset = [assdf, df1, df2, df3]

# %%
assdf.columns
# Out:
# Index(['Unnamed: 0', 'Wave 3_Patients Admitted Due to COVID',
#        'Wave 3_Patients Admitted Not Due to COVID',
#        'Wave 3_Patients Newly Admitted', 'Wave 3_Patients Discharged',
#        'Wave 3_Patients Currently in ICU',
#        'Wave 3_Patients Currently ICU Intubated', 'Wave 3_Patients Expired',
#        'cluster', 'Median Income', 'Less than high school',
#        'High school graduate', 'Some college or associate's degree',
#        'Bachelor's degree or higher',
#        'Management, business, science, and arts occupations',
#        'Service occupations', 'Sales and office occupations',
#        'Natural resources, construction, and maintenance occupations',
#        'Production, transportation, and material moving occupations',
#        'Unemployed', 'POVERTY'],
#       dtype='object')

# %%
for x in dataset:
    testfunc('POVERTY', x,yesgraph = False)
# Out:
# Test Statistic: 0.6878352950390223
# Critical Values: [0.542 0.617 0.741 0.864 1.028]
# Significance Levels: [15.  10.   5.   2.5  1. ]
# Data does not look normal (significance level 15.0%)
# Data does not look normal (significance level 10.0%)
# Data looks very likely normal (significance level 5.0%)
# Data looks very likely normal (significance level 2.5%)
# Data looks very likely normal (significance level 1.0%)
# Mean: 5.6192982456140355
# Median: 5.4
# Range: 7.999999999999999
# Test Statistic: 0.17931304068262044
# Critical Values: [0.497 0.566 0.679 0.792 0.942]
# Significance Levels: [15.  10.   5.   2.5  1. ]
# Data looks likely normal (significance level 15.0%)
# Data looks likely normal (significance level 10.0%)
# Data looks very likely normal (significance level 5.0%)
# Data looks very likely normal (significance level 2.5%)
# Data looks very likely normal (significance level 1.0%)
# Mean: 5.2846153846153845
# Median: 5.4
# Range: 3.8999999999999995
# Test Statistic: 1.1566395986227853
# Critical Values: [0.506 0.577 0.692 0.807 0.96 ]
# Significance Levels: [15.  10.   5.   2.5  1. ]
# Data does not look normal (significance level 15.0%)
# Data does not look normal (significance level 10.0%)
# Data does not look normal (significance level 5.0%)
# Data does not look normal (significance level 2.5%)
# Data does not look normal (significance level 1.0%)
# Mean: 5.7700000000000005
# Median: 5.6
# Range: 7.199999999999999
# Test Statistic: 0.24863660798424192
# Critical Values: [0.513 0.584 0.701 0.817 0.972]
# Significance Levels: [15.  10.   5.   2.5  1. ]
# Data looks likely normal (significance level 15.0%)
# Data looks likely normal (significance level 10.0%)
# Data looks very likely normal (significance level 5.0%)
# Data looks very likely normal (significance level 2.5%)
# Data looks very likely normal (significance level 1.0%)
# Mean: 5.675000000000001
# Median: 5.6
# Range: 3.9000000000000004

# %%
assdf
# Out:
#       Unnamed: 0  Wave 3_Patients Admitted Due to COVID  \
# 0         ALBANY                              15.801276
# 1       ALLEGANY                               6.164191
# 2          BRONX                               8.309570
# 3         BROOME                               9.074910
# 4    CATTARAUGUS                               9.567784
# 5         CAYUGA                               5.186425
# 6     CHAUTAUQUA                               6.367679
# 7        CHEMUNG                               7.526422
# 8       CHENANGO                               1.925224
# 9        CLINTON                              10.218918
# 10      COLUMBIA                              10.311003
# 11      CORTLAND                               9.176557
# 12      DELAWARE                               4.496760
# 13      DUTCHESS                               9.958973
# 14          ERIE                               9.283962
# 15         ESSEX                               1.357844
# 16      FRANKLIN                               4.683572
# 17        FULTON                               6.961446
# 18       GENESEE                               8.277957
# 19      HERKIMER                               3.212255
# 20     JEFFERSON                               4.465453
# 21         KINGS                               7.463415
# 22         LEWIS                               5.414920
# 23    LIVINGSTON                               9.752406
# 24       MADISON                               5.791864
# 25        MONROE                              12.474254
# 26    MONTGOMERY                               9.742707
# 27        NASSAU                              11.124489
# 28      NEW YORK                              11.878852
# 29       NIAGARA                               5.086935
# 30        ONEIDA                               6.879783
# 31      ONONDAGA                               9.947518
# 32       ONTARIO                              12.489511
# 33        ORANGE                               9.076336
# 34       ORLEANS                               0.732356
# 35        OSWEGO                               4.170615
# 36        OTSEGO                              11.935016
# 37        PUTNAM                               4.894441
# 38        QUEENS                               6.001173
# 39    RENSSELAER                               6.286097
# 40      RICHMOND                               9.885602
# 41      ROCKLAND                               6.746616
# 42      SARATOGA                               3.515918
# 43   SCHENECTADY                               5.344120
# 44     SCHOHARIE                               4.818665
# 45      SCHUYLER                               4.063430
# 46  ST. LAWRENCE                               4.587137
# 47       STEUBEN                               7.601338
# 48       SUFFOLK                               9.110252
# 49      SULLIVAN                               5.366932
# 50      TOMPKINS                               4.879034
# 51        ULSTER                               5.019927
# 52        WARREN                               9.945508
# 53         WAYNE                               7.377988
# 54   WESTCHESTER                               8.058779
# 55       WYOMING                               5.906440
# 56         YATES                               1.895927
#
#     Wave 3_Patients Admitted Not Due to COVID  Wave 3_Patients Newly Admitted  \
# 0                                    5.404243                        4.730517
# 1                                    0.962136                        3.326706
# 2                                    7.636697                        2.064403
# 3                                   10.451398                        1.803543
# 4                                    4.415144                        4.159479
# 5                                    0.824661                        2.354756
# 6                                    2.818870                        2.812936
# 7                                    6.266016                        4.123327
# 8                                    0.481306                        1.203265
# 9                                   10.911565                        1.707897
# 10                                   5.881455                        2.177861
# 11                                   0.485532                        3.204512
# 12                                   2.034655                        0.820701
# 13                                   4.165360                        3.374274
# 14                                   6.945109                        2.317418
# 15                                   0.587724                        0.810653
# 16                                   3.759602                        2.994937
# 17                                   0.000000                        2.812992
# 18                                   3.594034                        1.531033
# 19                                   0.214150                        0.604660
# 20                                   4.140929                        3.277694
# 21                                   6.618641                        1.636940
# 22                                   0.968986                        4.217937
# 23                                   0.441064                        0.992393
# 24                                   1.191787                        2.639753
# 25                                  13.244356                        3.329793
# 26                                   6.010807                        4.022499
# 27                                   9.076098                        2.731731
# 28                                  13.971491                        3.189485
# 29                                   2.187240                        1.389289
# 30                                   4.510370                        3.348509
# 31                                   4.655000                        4.356113
# 32                                   6.325594                        4.742511
# 33                                   6.055924                        3.599953
# 34                                   1.276929                        0.732356
# 35                                   1.250540                        1.579290
# 36                                   4.867208                        4.181139
# 37                                   1.613382                        1.683191
# 38                                   6.112977                        1.916092
# 39                                   4.052816                        2.369628
# 40                                   9.090964                        2.990589
# 41                                   4.099918                        2.185429
# 42                                   1.878587                        1.614813
# 43                                   2.784694                        2.343744
# 44                                   0.790363                        1.453248
# 45                                   0.000000                        1.100512
# 46                                   3.763267                        2.674084
# 47                                   1.748551                        3.351389
# 48                                   6.352353                        3.314940
# 49                                   3.150784                        1.936721
# 50                                   3.911825                        2.027558
# 51                                   2.237096                        1.470568
# 52                                   8.228381                        6.511254
# 53                                   4.265788                        0.937809
# 54                                   7.054166                        2.895428
# 55                                   1.607449                        2.859764
# 56                                   1.987665                        0.947964
#
#     Wave 3_Patients Discharged  Wave 3_Patients Currently in ICU  \
# 0                     4.343125                          6.684322
# 1                     3.767005                          4.305149
# 2                     2.761454                          3.543901
# 3                     5.460198                          4.735730
# 4                     4.690476                          5.349306
# 5                     2.036814                          1.371124
# 6                     2.551819                          3.685302
# 7                     3.367083                          6.662144
# 8                     1.893137                          2.518835
# 9                     3.074215                          5.228063
# 10                    1.931775                          3.346770
# 11                    2.945561                          5.486513
# 12                    3.299903                          0.000000
# 13                    2.869925                          3.753176
# 14                    3.721048                          5.445416
# 15                    1.256513                          0.000000
# 16                    3.345409                          4.667642
# 17                    2.131055                          4.347352
# 18                    3.542135                          6.707999
# 19                    0.579466                          0.000000
# 20                    3.433466                          2.901246
# 21                    2.671656                          2.544566
# 22                    3.647946                          2.080469
# 23                    2.168563                          6.468933
# 24                    2.383575                          2.227640
# 25                    4.312371                          8.692575
# 26                    4.313098                          8.687374
# 27                    3.784693                          3.836798
# 28                    4.166497                          5.778454
# 29                    1.713456                          4.363793
# 30                    2.901389                          4.817154
# 31                    4.085843                          6.418113
# 32                    4.823350                          9.646699
# 33                    3.422503                          3.556534
# 34                    1.032810                          0.000000
# 35                    1.431030                          2.443065
# 36                    4.349420                          3.482125
# 37                    1.512545                          2.326993
# 38                    1.991678                          1.816256
# 39                    2.289700                          2.990245
# 40                    2.995174                          6.172198
# 41                    2.095862                          1.840597
# 42                    1.460409                          2.415786
# 43                    2.516290                          2.497118
# 44                    1.223788                          0.000000
# 45                    1.777751                          0.000000
# 46                    3.358315                          4.740739
# 47                    3.764241                          3.132820
# 48                    3.251888                          3.764743
# 49                    2.553388                          2.399221
# 50                    2.034722                          3.352993
# 51                    1.337259                          1.162290
# 52                    5.808269                          6.004183
# 53                    2.672342                          5.045913
# 54                    2.691036                          2.885624
# 55                    2.224261                          5.588689
# 56                    1.070281                          0.000000
#
#     Wave 3_Patients Currently ICU Intubated  Wave 3_Patients Expired  cluster  \
# 0                                  2.952363                 0.510107        2
# 1                                  0.423992                 0.407685        3
# 2                                  1.344203                 0.247955        2
# 3                                  2.829237                 0.449933        2
# 4                                  4.523310                 0.845662        2
# 5                                  0.248392                 0.218585        1
# 6                                  1.661650                 0.522233        3
# 7                                  2.466794                 0.765246        2
# 8                                  0.721959                 0.128348        1
# 9                                  3.131145                 0.550322        2
# 10                                 2.313208                 0.319912        2
# 11                                 0.550270                 0.323688        3
# 12                                 0.000000                 0.017098        1
# 13                                 2.178685                 0.384022        3
# 14                                 3.770270                 0.516040        2
# 15                                 0.000000                 0.162131        1
# 16                                 1.210719                 0.223027        3
# 17                                 0.610902                 0.355176        3
# 18                                 4.372526                 0.544944        3
# 19                                 0.000000                 0.062985        1
# 20                                 0.642558                 0.266110        3
# 21                                 1.428169                 0.302358        3
# 22                                 0.028500                 0.056999        3
# 23                                 5.231504                 0.428812        3
# 24                                 0.957885                 0.256179        3
# 25                                 6.185754                 0.415975        2
# 26                                 4.924885                 0.749439        2
# 27                                 1.974575                 0.321859        2
# 28                                 3.098714                 0.353692        2
# 29                                 2.956692                 0.363353        3
# 30                                 2.650087                 0.574403        3
# 31                                 2.887117                 0.486486        2
# 32                                 3.880237                 0.572604        2
# 33                                 2.265308                 0.375664        2
# 34                                 0.000000                 0.037557        1
# 35                                 0.915344                 0.219167        1
# 36                                 2.368881                 0.530733        2
# 37                                 1.000607                 0.147376        1
# 38                                 1.245901                 0.238094        3
# 39                                 1.669083                 0.263292        3
# 40                                 2.723163                 0.287292        2
# 41                                 0.949408                 0.219439        3
# 42                                 1.006846                 0.250907        1
# 43                                 1.888416                 0.254025        3
# 44                                 0.000000                 0.152973        1
# 45                                 0.000000                 0.000000        1
# 46                                 1.445262                 0.237386        3
# 47                                 0.590945                 0.429043        3
# 48                                 2.151707                 0.329161        2
# 49                                 1.021355                 0.163802        3
# 50                                 0.415542                 0.121797        3
# 51                                 0.695708                 0.129143        1
# 52                                 1.924565                 0.910423        2
# 53                                 2.763633                 0.365165        3
# 54                                 1.905899                 0.274534        2
# 55                                 1.401845                 0.448590        3
# 56                                 0.000000                 0.152897        1
#
#     Median Income  ...  High school graduate  \
# 0           73810  ...              0.229183
# 1           54375  ...              0.330523
# 2           43726  ...              0.279206
# 3           53982  ...              0.300806
# 4           53537  ...              0.398067
# 5           59602  ...              0.325200
# 6           50408  ...              0.342276
# 7           58175  ...              0.347206
# 8           55690  ...              0.413009
# 9           62470  ...              0.348376
# 10          73065  ...              0.304501
# 11          62163  ...              0.293911
# 12          52757  ...              0.408892
# 13          87112  ...              0.265320
# 14          62578  ...              0.264967
# 15          61563  ...              0.332433
# 16          55279  ...              0.374235
# 17          55240  ...              0.374394
# 18          63734  ...              0.380937
# 19          60561  ...              0.354107
# 20          58271  ...              0.350407
# 21          67753  ...              0.254811
# 22          60049  ...              0.428599
# 23          64467  ...              0.302376
# 24          63312  ...              0.339582
# 25          66317  ...              0.237639
# 26          53533  ...              0.354184
# 27         126576  ...              0.221926
# 28          93956  ...              0.130376
# 29          60834  ...              0.319115
# 30          61733  ...              0.303779
# 31          66012  ...              0.253075
# 32          70694  ...              0.264604
# 33          85640  ...              0.290489
# 34          54882  ...              0.406846
# 35          61983  ...              0.360476
# 36          60523  ...              0.336160
# 37         111617  ...              0.261408
# 38          75886  ...              0.265639
# 39          76731  ...              0.279743
# 40          89427  ...              0.295427
# 41          99707  ...              0.230484
# 42          90800  ...              0.240936
# 43          69891  ...              0.279606
# 44          64220  ...              0.360073
# 45          56437  ...              0.361270
# 46          54351  ...              0.347092
# 47          58652  ...              0.353991
# 48         111660  ...              0.261578
# 49          63393  ...              0.326859
# 50          64260  ...              0.162924
# 51          71040  ...              0.279254
# 52          68765  ...              0.278850
# 53          64152  ...              0.332799
# 54         105387  ...              0.192272
# 55          60013  ...              0.371472
# 56          57635  ...              0.329298
#
#     Some college or associate's degree  Bachelor's degree or higher  \
# 0                             0.293259                     0.405160
# 1                             0.400151                     0.188790
# 2                             0.276540                     0.195161
# 3                             0.345614                     0.264026
# 4                             0.309148                     0.184619
# 5                             0.340643                     0.207692
# 6                             0.335832                     0.212906
# 7                             0.318125                     0.222867
# 8                             0.294282                     0.174116
# 9                             0.303400                     0.230762
# 10                            0.270478                     0.335547
# 11                            0.381550                     0.237770
# 12                            0.287173                     0.207898
# 13                            0.302118                     0.344427
# 14                            0.318951                     0.337063
# 15                            0.284942                     0.288026
# 16                            0.298752                     0.198626
# 17                            0.323453                     0.171872
# 18                            0.338098                     0.207576
# 19                            0.349006                     0.202290
# 20                            0.347299                     0.216572
# 21                            0.211016                     0.375078
# 22                            0.300596                     0.178844
# 23                            0.372498                     0.250801
# 24                            0.362116                     0.231043
# 25                            0.305002                     0.368758
# 26                            0.337975                     0.183975
# 27                            0.246235                     0.450258
# 28                            0.161657                     0.596324
# 29                            0.344821                     0.250686
# 30                            0.339444                     0.246103
# 31                            0.322454                     0.339013
# 32                            0.318476                     0.348712
# 33                            0.317809                     0.288944
# 34                            0.299491                     0.161048
# 35                            0.348963                     0.191724
# 36                            0.312154                     0.278962
# 37                            0.270636                     0.393684
# 38                            0.243055                     0.324185
# 39                            0.319639                     0.320865
# 40                            0.256693                     0.334451
# 41                            0.264490                     0.389304
# 42                            0.286989                     0.405273
# 43                            0.320374                     0.309504
# 44                            0.329620                     0.217036
# 45                            0.315637                     0.228512
# 46                            0.340651                     0.203789
# 47                            0.309817                     0.242158
# 48                            0.281419                     0.361669
# 49                            0.287542                     0.250695
# 50                            0.362544                     0.434431
# 51                            0.313616                     0.320889
# 52                            0.315034                     0.317359
# 53                            0.336759                     0.228894
# 54                            0.221289                     0.475422
# 55                            0.334635                     0.175512
# 56                            0.293921                     0.220715
#
#     Management, business, science, and arts occupations  Service occupations  \
# 0                                            0.485468               0.162839
# 1                                            0.349464               0.191168
# 2                                            0.269325               0.338137
# 3                                            0.402323               0.200060
# 4                                            0.318223               0.198814
# 5                                            0.355411               0.193302
# 6                                            0.329995               0.199419
# 7                                            0.346874               0.188080
# 8                                            0.322713               0.165240
# 9                                            0.342979               0.210082
# 10                                           0.420326               0.174928
# 11                                           0.372947               0.221809
# 12                                           0.323891               0.196343
# 13                                           0.429931               0.185132
# 14                                           0.418492               0.174063
# 15                                           0.381327               0.204397
# 16                                           0.330581               0.237735
# 17                                           0.301386               0.195079
# 18                                           0.326860               0.171147
# 19                                           0.338764               0.177935
# 20                                           0.346294               0.200114
# 21                                           0.454633               0.215208
# 22                                           0.336009               0.194215
# 23                                           0.376789               0.175976
# 24                                           0.381364               0.195161
# 25                                           0.463218               0.166438
# 26                                           0.322638               0.180051
# 27                                           0.486645               0.156733
# 28                                           0.628356               0.135047
# 29                                           0.357349               0.169188
# 30                                           0.392578               0.206221
# 31                                           0.437007               0.167428
# 32                                           0.444150               0.163436
# 33                                           0.378330               0.185543
# 34                                           0.287858               0.172265
# 35                                           0.327701               0.177935
# 36                                           0.365182               0.198466
# 37                                           0.452477               0.173793
# 38                                           0.367347               0.234811
# 39                                           0.446844               0.158002
# 40                                           0.427960               0.203268
# 41                                           0.466356               0.180780
# 42                                           0.481798               0.143676
# 43                                           0.427451               0.173433
# 44                                           0.367793               0.162649
# 45                                           0.344823               0.205471
# 46                                           0.375608               0.221232
# 47                                           0.387746               0.161303
# 48                                           0.424211               0.165166
# 49                                           0.364971               0.230506
# 50                                           0.551352               0.156524
# 51                                           0.403506               0.202460
# 52                                           0.398599               0.189315
# 53                                           0.351840               0.163310
# 54                                           0.507145               0.167484
# 55                                           0.318132               0.192531
# 56                                           0.318399               0.210430
#
#     Sales and office occupations  \
# 0                       0.223278
# 1                       0.188764
# 2                       0.207589
# 3                       0.210401
# 4                       0.198239
# 5                       0.193675
# 6                       0.193522
# 7                       0.229000
# 8                       0.189240
# 9                       0.207613
# 10                      0.193270
# 11                      0.176591
# 12                      0.194242
# 13                      0.210446
# 14                      0.230168
# 15                      0.189235
# 16                      0.217227
# 17                      0.210201
# 18                      0.213461
# 19                      0.219904
# 20                      0.222554
# 21                      0.189488
# 22                      0.178915
# 23                      0.188551
# 24                      0.193121
# 25                      0.208399
# 26                      0.209653
# 27                      0.217239
# 28                      0.174062
# 29                      0.235263
# 30                      0.214583
# 31                      0.226156
# 32                      0.199641
# 33                      0.225377
# 34                      0.209257
# 35                      0.220925
# 36                      0.223689
# 37                      0.205621
# 38                      0.201378
# 39                      0.209618
# 40                      0.199348
# 41                      0.208440
# 42                      0.208690
# 43                      0.211786
# 44                      0.193054
# 45                      0.200932
# 46                      0.183392
# 47                      0.182607
# 48                      0.227681
# 49                      0.184240
# 50                      0.176008
# 51                      0.195328
# 52                      0.221999
# 53                      0.209393
# 54                      0.189009
# 55                      0.202647
# 56                      0.175266
#
#     Natural resources, construction, and maintenance occupations  \
# 0                                            0.047515
# 1                                            0.103841
# 2                                            0.062415
# 3                                            0.063344
# 4                                            0.110664
# 5                                            0.104176
# 6                                            0.097187
# 7                                            0.075578
# 8                                            0.111719
# 9                                            0.083539
# 10                                           0.092493
# 11                                           0.099675
# 12                                           0.116330
# 13                                           0.087633
# 14                                           0.062678
# 15                                           0.116049
# 16                                           0.095936
# 17                                           0.106306
# 18                                           0.133164
# 19                                           0.104587
# 20                                           0.109897
# 21                                           0.056101
# 22                                           0.158850
# 23                                           0.126129
# 24                                           0.099302
# 25                                           0.054951
# 26                                           0.091749
# 27                                           0.063322
# 28                                           0.020215
# 29                                           0.085236
# 30                                           0.073979
# 31                                           0.063394
# 32                                           0.087062
# 33                                           0.093749
# 34                                           0.154490
# 35                                           0.114496
# 36                                           0.105576
# 37                                           0.091838
# 38                                           0.083406
# 39                                           0.079174
# 40                                           0.082892
# 41                                           0.062321
# 42                                           0.072616
# 43                                           0.080586
# 44                                           0.138179
# 45                                           0.098013
# 46                                           0.097267
# 47                                           0.113504
# 48                                           0.088137
# 49                                           0.094119
# 50                                           0.048095
# 51                                           0.097926
# 52                                           0.076109
# 53                                           0.108873
# 54                                           0.068331
# 55                                           0.145943
# 56                                           0.131932
#
#     Production, transportation, and material moving occupations  Unemployed  \
# 0                                            0.080900                   3.2
# 1                                            0.166762                   3.6
# 2                                            0.122533                   6.6
# 3                                            0.123871                   4.2
# 4                                            0.174060                   3.4
# 5                                            0.153435                   2.6
# 6                                            0.179877                   3.0
# 7                                            0.160468                   3.5
# 8                                            0.211088                   4.2
# 9                                            0.155786                   2.4
# 10                                           0.118983                   3.5
# 11                                           0.128978                   3.7
# 12                                           0.169194                   2.5
# 13                                           0.086860                   3.2
# 14                                           0.114599                   3.2
# 15                                           0.108992                   3.1
# 16                                           0.118521                   3.3
# 17                                           0.187027                   3.0
# 18                                           0.155369                   3.2
# 19                                           0.158810                   3.2
# 20                                           0.121140                   3.0
# 21                                           0.084570                   4.5
# 22                                           0.132012                   3.0
# 23                                           0.132555                   2.8
# 24                                           0.131053                   2.4
# 25                                           0.106993                   3.4
# 26                                           0.195909                   3.8
# 27                                           0.076062                   3.0
# 28                                           0.042320                   4.4
# 29                                           0.152963                   3.5
# 30                                           0.112640                   2.7
# 31                                           0.106015                   3.7
# 32                                           0.105711                   2.5
# 33                                           0.117000                   3.4
# 34                                           0.176131                   3.5
# 35                                           0.158943                   4.4
# 36                                           0.107088                   3.2
# 37                                           0.076271                   3.1
# 38                                           0.113058                   4.4
# 39                                           0.106362                   3.4
# 40                                           0.086532                   3.3
# 41                                           0.082102                   3.8
# 42                                           0.093220                   2.4
# 43                                           0.106745                   4.3
# 44                                           0.138325                   3.3
# 45                                           0.150761                   3.3
# 46                                           0.122501                   3.3
# 47                                           0.154839                   3.7
# 48                                           0.094805                   3.1
# 49                                           0.126164                   4.5
# 50                                           0.068021                   2.8
# 51                                           0.100779                   3.1
# 52                                           0.113978                   2.6
# 53                                           0.166584                   2.5
# 54                                           0.068031                   4.0
# 55                                           0.140748                   2.3
# 56                                           0.163974                   1.8
#
#     POVERTY
# 0       4.9
# 1       6.7
# 2      11.2
# 3       7.5
# 4       6.0
# 5       4.5
# 6       5.4
# 7       6.1
# 8       7.0
# 9       4.3
# 10      5.9
# 11      5.9
# 12      4.7
# 13      5.2
# 14      5.1
# 15      5.4
# 16      6.6
# 17      5.1
# 18      4.9
# 19      5.4
# 20      6.0
# 21      7.1
# 22      5.0
# 23      4.8
# 24      4.2
# 25      5.3
# 26      6.4
# 27      4.5
# 28      6.6
# 29      5.8
# 30      4.7
# 31      5.9
# 32      4.0
# 33      5.4
# 34      6.4
# 35      7.1
# 36      5.7
# 37      4.8
# 38      7.0
# 39      5.4
# 40      5.5
# 41      6.0
# 42      3.6
# 43      6.9
# 44      5.8
# 45      5.7
# 46      6.3
# 47      6.3
# 48      4.8
# 49      8.0
# 50      4.7
# 51      5.1
# 52      4.2
# 53      4.1
# 54      6.1
# 55      4.1
# 56      3.2
#
# [57 rows x 21 columns]
