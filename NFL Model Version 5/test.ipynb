# %%
from pathlib import Path
import pandas as pd

# %%
Weekpath = Path("WeekData")
DYearpath = Path("YearData/Def")
OYearpath = Path("YearData/Off")

# %%
finaldf = pd.DataFrame()
Weeklist = []
DYearlist = []
OYearlist = []
for x in Weekpath.iterdir():
    Weeklist.append(x)
for x in DYearpath.iterdir():
    DYearlist.append(x)
for x in OYearpath.iterdir():
    OYearlist.append(x)

# %%
for x in range(len(Weeklist)):
   df2024 = pd.read_csv(Weeklist[x])
   df2024 = df2024.dropna()
   ddf2024 = pd.read_csv(DYearlist[x])
   odf2024 = pd.read_csv(OYearlist[x])
   ddf2024 = ddf2024.dropna()
   odf2024 = odf2024.dropna()
   #columnslist2 = list(ddf2024.columns.values)
   #for x in range(0, len(ddf2024.columns)):
      #if columnslist2[x] == "Tm":
         #pass
      #else:
         #columnslist2[x] = "D" + columnslist2[x] 
   #ddf2024.columns.values[0:len(ddf2024.columns)] = columnslist2
   ddf2024.iloc[0] = ddf2024.iloc[0].apply(lambda x: x if x == "Tm" else "D" + x)
   header = ddf2024.iloc[0]
   ddf2024.columns = header
   ddf2024 = ddf2024[1:]
   header = odf2024.iloc[0]
   odf2024.columns = header
   odf2024 = odf2024[1:]
   merged = pd.merge(odf2024,ddf2024, left_on='Tm', right_on='Tm', how='left')
   merged2 = pd.merge(odf2024,ddf2024, left_on='Tm', right_on='Tm', how='left')
   columnslist = list(merged2.columns.values)
   bestcolumnslist = list(merged.columns.values)
   len(merged2.columns)
   for x in range(0, len(merged2.columns)):
      if columnslist[x] == "Tm":
         pass
      else:
         columnslist[x] = "T2" + columnslist[x]
   merged2.columns.values[0:len(merged2.columns)] = columnslist
   merged.columns.values[0:len(merged2.columns)] = bestcolumnslist
   df2024 = df2024.rename(columns={"Day" : "Day", "Time" : "Time", "Winner/tie" : "Team1", "Loser/tie" : "Team2", "PtsW" : "PtsT1", "PtsL" : "PtsT2","YdsW" : "YdsT1","TOW" : "TOT1","YdsL" : "YdsT2T2","TOL" : "TOT2"})
   finalmerge = pd.merge(df2024,merged, left_on='Team1', right_on='Tm', how='left')
   finalmerge = finalmerge.drop("Tm", axis='columns')
   finalfinalmerge = pd.merge(finalmerge,merged2, left_on='Team2', right_on='Tm', how='left')
   finalfinalmerge = finalfinalmerge.drop("Tm", axis='columns')
   finaldf = pd.concat([finaldf, finalfinalmerge], sort=False)
   #finaldf = df2024.copy()

# %%
finaldf = finaldf.dropna()
finaldf = finaldf.drop("Team1", axis='columns')
finaldf = finaldf.drop("Team2", axis='columns')
finaldf = finaldf.drop("Day", axis='columns')
finaldf = finaldf.drop("Time", axis='columns')
for x in finaldf.columns:
    finaldf[x] = finaldf[x].astype(str).astype(float)
# if using point per game 
finaldf["PPP"] = finaldf["PF"]/finaldf["Ply"]
finaldf["PPPA"] = finaldf["DPA"]/finaldf["DPly"]
finaldf["PPPD"] = finaldf["PPP"] - finaldf["PPPA"]
finaldf["T2PPP"] = finaldf["T2PF"]/finaldf["T2Ply"]
finaldf["T2PPPA"] = finaldf["T2DPA"]/finaldf["T2DPly"]
finaldf["T2PPPD"] = finaldf["T2PPP"] - finaldf["T2PPPA"]
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
correlation_matrix = finaldf.corr(method='pearson')
correlation_matrix.to_csv("matrix.csv")

# %%
finaldf2 = finaldf.copy()
xff = finaldf2.drop("PtsT1", axis='columns')
xff = xff.drop("PtsT2", axis='columns')
xff = xff.drop("TOT1", axis='columns')
xff = xff.drop("TOT2", axis='columns')
x_trainM1, x_testM1, y_trainM1, y_testM1 = train_test_split(xff,finaldf2[["PtsT1","PtsT2"]], test_size=0.2, random_state=42)
model1 = LinearRegression()
model1.fit(x_trainM1, y_trainM1)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
y_predM1 = model1.predict(x_testM1)
r2M1 = r2_score(y_testM1, y_predM1)
print(f"Model 1: R-squared (R²) Score: {r2M1}")
mseM1 = mean_squared_error(y_testM1, y_predM1)
print(f"Model1: Mean Squared Error: {mseM1}")
# Out:
# Model 1: R-squared (R²) Score: 0.5045510455181548
# Model1: Mean Squared Error: 29.917962511711046

# %%
plt.scatter(y_testM1, y_predM1)
plt.show()

# %%
DYearpath = Path("predictData/Def")
OYearpath = Path("predictData/Off")
DYearlist = []
OYearlist = []
for x in DYearpath.iterdir():
    DYearlist.append(x)
for x in OYearpath.iterdir():
    OYearlist.append(x)

team_df = pd.DataFrame()
team_df2 = pd.DataFrame()
ddf2024 = pd.read_csv(DYearlist[0])
odf2024 = pd.read_csv(OYearlist[0])
ddf2024 = ddf2024.dropna()
odf2024 = odf2024.dropna()
#columnslist2 = list(ddf2024.columns.values)
#for x in range(0, len(ddf2024.columns)):
   #if columnslist2[x] == "Tm":
      #pass
   #else:
      #columnslist2[x] = "D" + columnslist2[x] 
#ddf2024.columns.values[0:len(ddf2024.columns)] = columnslist2
ddf2024.iloc[0] = ddf2024.iloc[0].apply(lambda x: x if x == "Tm" else "D" + x)
header = ddf2024.iloc[0]
ddf2024.columns = header
ddf2024 = ddf2024[1:]
header = odf2024.iloc[0]
odf2024.columns = header
odf2024 = odf2024[1:]
merged = pd.merge(odf2024,ddf2024, left_on='Tm', right_on='Tm', how='left')
merged2 = pd.merge(odf2024,ddf2024, left_on='Tm', right_on='Tm', how='left')
columnslist = list(merged2.columns.values)
bestcolumnslist = list(merged.columns.values)
len(merged2.columns)
for x in range(0, len(merged2.columns)):
   if columnslist[x] == "Tm":
      pass
   else:
      columnslist[x] = "T2" + columnslist[x]
merged2.columns.values[0:len(merged2.columns)] = columnslist
merged.columns.values[0:len(merged2.columns)] = bestcolumnslist
team_df = pd.concat([team_df, merged], sort=False)
team_df2 = pd.concat([team_df2, merged2], sort=False)

# %%
import numpy as np

# %%
np.sort(df2024["Team1"].unique())
# Out:
# array(['Arizona Cardinals', 'Atlanta Falcons', 'Baltimore Ravens',
#        'Buffalo Bills', 'Carolina Panthers', 'Chicago Bears',
#        'Cincinnati Bengals', 'Cleveland Browns', 'Dallas Cowboys',
#        'Denver Broncos', 'Detroit Lions', 'Green Bay Packers',
#        'Houston Texans', 'Indianapolis Colts', 'Jacksonville Jaguars',
#        'Kansas City Chiefs', 'Las Vegas Raiders', 'Los Angeles Chargers',
#        'Los Angeles Rams', 'Miami Dolphins', 'Minnesota Vikings',
#        'New England Patriots', 'New Orleans Saints', 'New York Giants',
#        'New York Jets', 'Philadelphia Eagles', 'Pittsburgh Steelers',
#        'San Francisco 49ers', 'Seattle Seahawks', 'Tampa Bay Buccaneers',
#        'Tennessee Titans', 'Washington Commanders'], dtype=object)

# %%
team1list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team2list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

predict = {
    "Team1" : team1list,
    "Team2" : team2list
}
df_predict = pd.DataFrame(predict)
finalmerge = pd.merge(df_predict,team_df, left_on='Team1', right_on='Tm', how='left')
finalmerge = finalmerge.drop("Tm", axis='columns')
finalfinalmerge = pd.merge(finalmerge,team_df2, left_on='Team2', right_on='Tm', how='left')
finalpredict = finalfinalmerge.drop("Tm", axis='columns')
finalpredict = finalpredict.drop("Team1", axis='columns')
finalpredict = finalpredict.drop("Team2", axis='columns')
for x in finalpredict.columns:
    finalpredict[x] = finalpredict[x].astype(str).astype(float)
finalpredict["PPP"] = finalpredict["PF"]/finalpredict["Ply"]
finalpredict["PPPA"] = finalpredict["DPA"]/finalpredict["DPly"]
finalpredict["PPPD"] = finalpredict["PPP"] - finalpredict["PPPA"]
finalpredict["T2PPP"] = finalpredict["T2PF"]/finalpredict["T2Ply"]
finalpredict["T2PPPA"] = finalpredict["T2DPA"]/finalpredict["T2DPly"]
finalpredict["T2PPPD"] = finalpredict["T2PPP"] - finalpredict["T2PPPA"]
numgames = 17 #Num of games so far in season
finalpredict["YdsT1"] = (finalpredict["Y/P"] * finalpredict["Ply"]) / numgames
finalpredict["YdsT2T2"] = (finalpredict["T2Y/P"] * finalpredict["T2Ply"]) / numgames
column_to_move = finalpredict.pop('YdsT1')
finalpredict.insert(0, 'YdsT1', column_to_move) 
column_to_move = finalpredict.pop('YdsT2T2')
finalpredict.insert(1, 'YdsT2T2', column_to_move) 
firstg_pred = model1.predict(finalpredict)

# %%
team2list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team1list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

predict = {
    "Team1" : team1list,
    "Team2" : team2list
}
df_predict = pd.DataFrame(predict)
finalmerge = pd.merge(df_predict,team_df, left_on='Team1', right_on='Tm', how='left')
finalmerge = finalmerge.drop("Tm", axis='columns')
finalfinalmerge = pd.merge(finalmerge,team_df2, left_on='Team2', right_on='Tm', how='left')
finalpredict = finalfinalmerge.drop("Tm", axis='columns')
finalpredict = finalpredict.drop("Team1", axis='columns')
finalpredict = finalpredict.drop("Team2", axis='columns')
for x in finalpredict.columns:
    finalpredict[x] = finalpredict[x].astype(str).astype(float)
finalpredict["PPP"] = finalpredict["PF"]/finalpredict["Ply"]
finalpredict["PPPA"] = finalpredict["DPA"]/finalpredict["DPly"]
finalpredict["PPPD"] = finalpredict["PPP"] - finalpredict["PPPA"]
finalpredict["T2PPP"] = finalpredict["T2PF"]/finalpredict["T2Ply"]
finalpredict["T2PPPA"] = finalpredict["T2DPA"]/finalpredict["T2DPly"]
finalpredict["T2PPPD"] = finalpredict["T2PPP"] - finalpredict["T2PPPA"]
numgames = 17 #Num of games so far in season
finalpredict["YdsT1"] = (finalpredict["Y/P"] * finalpredict["Ply"]) / numgames
finalpredict["YdsT2T2"] = (finalpredict["T2Y/P"] * finalpredict["T2Ply"]) / numgames
column_to_move = finalpredict.pop('YdsT1')
finalpredict.insert(0, 'YdsT1', column_to_move) 
column_to_move = finalpredict.pop('YdsT2T2')
finalpredict.insert(1, 'YdsT2T2', column_to_move) 
secondg_pred = model1.predict(finalpredict)

# %%
finalpredictlist = []
for x in range(len(firstg_pred)):
    first = firstg_pred[x]
    second = secondg_pred[x]
    team1dif = (first[0] + second[1])/2
    team2dif = (first[1] + second[0])/2
    finalpredictlist.append([team1dif,team2dif])

# %%
team1list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team2list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

# %%
gamenum = 0
for x in finalpredictlist:
    print(f"Team1: {team1list[gamenum]} Team2: {team2list[gamenum]}")
    print(f"{x[0]} , {x[1]}")
    print(x[0] - x[1])
    print(x[0] + x[1])
    print("--------------------------")
    gamenum = gamenum + 1
# Out:
# Team1: Buffalo Bills Team2: Miami Dolphins
# 27.15354927339681 , 21.910626250045233
# 5.242923023351576
# 49.064175523442046
# --------------------------
# Team1: Las Vegas Raiders Team2: Baltimore Ravens
# 21.310342831126164 , 29.3054510163062
# -7.995108185180037
# 50.615793847432364
# --------------------------
# Team1: Los Angeles Chargers Team2: Carolina Panthers
# 24.51877750939834 , 15.997670527504368
# 8.521106981893972
# 40.51644803690271
# --------------------------
# Team1: New Orleans Saints Team2: Dallas Cowboys
# 22.036801744866295 , 18.87095930781113
# 3.165842437055165
# 40.90776105267743
# --------------------------
# Team1: Tampa Bay Buccaneers Team2: Detroit Lions
# 27.618169276736893 , 30.64117822537538
# -3.0230089486384877
# 58.25934750211228
# --------------------------
# Team1: Indianapolis Colts Team2: Green Bay Packers
# 22.07180601558422 , 25.87939003288304
# -3.8075840172988222
# 47.95119604846726
# --------------------------
# Team1: Cleveland Browns Team2: Jacksonville Jaguars
# 15.868000308073007 , 19.587064752467864
# -3.7190644443948564
# 35.455065060540875
# --------------------------
# Team1: San Francisco 49ers Team2: Minnesota Vikings
# 22.219285843911244 , 27.208532244185875
# -4.989246400274631
# 49.42781808809712
# --------------------------
# Team1: Seattle Seahawks Team2: New England Patriots
# 21.082447287179356 , 17.62072160327552
# 3.461725683903836
# 38.703168890454876
# --------------------------
# Team1: New York Jets Team2: Tennessee Titans
# 23.362570652506815 , 21.556863816509402
# 1.8057068359974124
# 44.91943446901622
# --------------------------
# Team1: New York Giants Team2: Washington Commanders
# 19.74409257334967 , 25.862618027219455
# -6.118525453869786
# 45.60671060056912
# --------------------------
# Team1: Los Angeles Rams Team2: Arizona Cardinals
# 20.82844637967367 , 21.660329547662474
# -0.8318831679888028
# 42.48877592733615
# --------------------------
# Team1: Pittsburgh Steelers Team2: Denver Broncos
# 20.169810123161028 , 23.039932918539122
# -2.8701227953780943
# 43.20974304170015
# --------------------------
# Team1: Cincinnati Bengals Team2: Kansas City Chiefs
# 24.683860908921474 , 24.872049533663752
# -0.1881886247422777
# 49.55591044258523
# --------------------------
# Team1: Chicago Bears Team2: Houston Texans
# 18.665170055277557 , 19.073847191533858
# -0.4086771362563013
# 37.739017246811414
# --------------------------
# Team1: Atlanta Falcons Team2: Philadelphia Eagles
# 24.264949100196343 , 27.380734780520452
# -3.115785680324109
# 51.645683880716795
# --------------------------

# %%
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(xff, finaldf2[["PtsT1","PtsT2"]], random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=X_train.shape[1:]),
    tf.keras.layers.Normalization(),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(2)
])
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_7 (Normalization) │ (None, 20)             │            41 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 2)              │            42 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,183 (8.53 KB)
#  Trainable params: 2,142 (8.37 KB)
#  Non-trainable params: 41 (168.00 B)

# %%
model.compile(loss="mean_squared_error", 
              optimizer="adam",
              metrics=["root_mean_squared_error",tf.keras.metrics.R2Score()])

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

history = model.fit(X_train,
                    y_train,
                    epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping_cb])
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10726.8486 - r2_score: -178.9354 - root_mean_squared_error: 99.2000 - val_loss: 334.0370 - val_r2_score: -3.7878 - val_root_mean_squared_error: 18.2767
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 182.2387 - r2_score: -1.5952 - root_mean_squared_error: 13.3691 - val_loss: 107.8620 - val_r2_score: -0.4883 - val_root_mean_squared_error: 10.3857
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.6194 - r2_score: -0.2615 - root_mean_squared_error: 9.2406 - val_loss: 71.9823 - val_r2_score: 0.0083 - val_root_mean_squared_error: 8.4842
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.9000 - r2_score: -0.0077 - root_mean_squared_error: 8.4720 - val_loss: 65.6099 - val_r2_score: 0.0946 - val_root_mean_squared_error: 8.1000
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.1474 - r2_score: 0.0663 - root_mean_squared_error: 7.9409 - val_loss: 64.1601 - val_r2_score: 0.1147 - val_root_mean_squared_error: 8.0100
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 64.2956 - r2_score: 0.0905 - root_mean_squared_error: 8.0158 - val_loss: 63.2208 - val_r2_score: 0.1279 - val_root_mean_squared_error: 7.9511
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.9442 - r2_score: 0.0977 - root_mean_squared_error: 7.9204 - val_loss: 62.2562 - val_r2_score: 0.1408 - val_root_mean_squared_error: 7.8903
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.6047 - r2_score: 0.1339 - root_mean_squared_error: 7.5208 - val_loss: 61.4566 - val_r2_score: 0.1521 - val_root_mean_squared_error: 7.8394
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.8489 - r2_score: 0.1265 - root_mean_squared_error: 7.9257 - val_loss: 60.8524 - val_r2_score: 0.1603 - val_root_mean_squared_error: 7.8008
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.8476 - r2_score: 0.1594 - root_mean_squared_error: 7.7341 - val_loss: 60.2832 - val_r2_score: 0.1682 - val_root_mean_squared_error: 7.7642
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.2378 - r2_score: 0.1439 - root_mean_squared_error: 7.8858 - val_loss: 58.7069 - val_r2_score: 0.1888 - val_root_mean_squared_error: 7.6620
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.7403 - r2_score: 0.1987 - root_mean_squared_error: 7.3290 - val_loss: 57.8826 - val_r2_score: 0.2001 - val_root_mean_squared_error: 7.6081
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.6226 - r2_score: 0.1394 - root_mean_squared_error: 7.4543 - val_loss: 57.3451 - val_r2_score: 0.2067 - val_root_mean_squared_error: 7.5727
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54.8410 - r2_score: 0.1780 - root_mean_squared_error: 7.4042 - val_loss: 56.1725 - val_r2_score: 0.2233 - val_root_mean_squared_error: 7.4948
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.0244 - r2_score: 0.2124 - root_mean_squared_error: 7.4158 - val_loss: 55.9280 - val_r2_score: 0.2272 - val_root_mean_squared_error: 7.4785
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.6907 - r2_score: 0.2281 - root_mean_squared_error: 7.1874 - val_loss: 54.5657 - val_r2_score: 0.2457 - val_root_mean_squared_error: 7.3869
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54.3938 - r2_score: 0.2128 - root_mean_squared_error: 7.3736 - val_loss: 53.9282 - val_r2_score: 0.2547 - val_root_mean_squared_error: 7.3436
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.4221 - r2_score: 0.2136 - root_mean_squared_error: 7.2372 - val_loss: 53.3124 - val_r2_score: 0.2633 - val_root_mean_squared_error: 7.3015
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.7356 - r2_score: 0.2500 - root_mean_squared_error: 7.3265 - val_loss: 53.5814 - val_r2_score: 0.2595 - val_root_mean_squared_error: 7.3199
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.6601 - r2_score: 0.2616 - root_mean_squared_error: 7.2495 - val_loss: 52.9967 - val_r2_score: 0.2674 - val_root_mean_squared_error: 7.2799
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.1258 - r2_score: 0.2669 - root_mean_squared_error: 7.1476 - val_loss: 52.2538 - val_r2_score: 0.2782 - val_root_mean_squared_error: 7.2287
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.5038 - r2_score: 0.2145 - root_mean_squared_error: 7.2445 - val_loss: 52.4732 - val_r2_score: 0.2747 - val_root_mean_squared_error: 7.2438
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.5982 - r2_score: 0.3211 - root_mean_squared_error: 7.1804 - val_loss: 51.4025 - val_r2_score: 0.2904 - val_root_mean_squared_error: 7.1696
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.1076 - r2_score: 0.2590 - root_mean_squared_error: 7.0053 - val_loss: 51.8402 - val_r2_score: 0.2839 - val_root_mean_squared_error: 7.2000
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.3414 - r2_score: 0.2756 - root_mean_squared_error: 7.1560 - val_loss: 51.2390 - val_r2_score: 0.2934 - val_root_mean_squared_error: 7.1581
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.8617 - r2_score: 0.2927 - root_mean_squared_error: 7.1280 - val_loss: 50.7802 - val_r2_score: 0.2999 - val_root_mean_squared_error: 7.1260
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.3819 - r2_score: 0.2608 - root_mean_squared_error: 7.2353 - val_loss: 51.1262 - val_r2_score: 0.2943 - val_root_mean_squared_error: 7.1503
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.5636 - r2_score: 0.3035 - root_mean_squared_error: 7.1072 - val_loss: 50.6816 - val_r2_score: 0.3002 - val_root_mean_squared_error: 7.1191
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.9581 - r2_score: 0.3050 - root_mean_squared_error: 7.2062 - val_loss: 50.9479 - val_r2_score: 0.2980 - val_root_mean_squared_error: 7.1378
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.7190 - r2_score: 0.2843 - root_mean_squared_error: 7.1755 - val_loss: 50.7755 - val_r2_score: 0.2984 - val_root_mean_squared_error: 7.1257
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.0201 - r2_score: 0.2856 - root_mean_squared_error: 7.0006 - val_loss: 49.7280 - val_r2_score: 0.3149 - val_root_mean_squared_error: 7.0518
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.9372 - r2_score: 0.3114 - root_mean_squared_error: 6.9217 - val_loss: 49.4329 - val_r2_score: 0.3196 - val_root_mean_squared_error: 7.0309
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2265 - r2_score: 0.3227 - root_mean_squared_error: 6.7216 - val_loss: 49.7615 - val_r2_score: 0.3133 - val_root_mean_squared_error: 7.0542
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.2395 - r2_score: 0.3525 - root_mean_squared_error: 6.7964 - val_loss: 48.5049 - val_r2_score: 0.3321 - val_root_mean_squared_error: 6.9645
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.1308 - r2_score: 0.3520 - root_mean_squared_error: 6.6410 - val_loss: 50.0801 - val_r2_score: 0.3118 - val_root_mean_squared_error: 7.0767
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.4174 - r2_score: 0.3567 - root_mean_squared_error: 6.5782 - val_loss: 49.0356 - val_r2_score: 0.3236 - val_root_mean_squared_error: 7.0025
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.4093 - r2_score: 0.3491 - root_mean_squared_error: 6.8107 - val_loss: 47.7610 - val_r2_score: 0.3433 - val_root_mean_squared_error: 6.9109
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.4249 - r2_score: 0.3818 - root_mean_squared_error: 6.6616 - val_loss: 49.1977 - val_r2_score: 0.3233 - val_root_mean_squared_error: 7.0141
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.1841 - r2_score: 0.3040 - root_mean_squared_error: 6.7931 - val_loss: 47.1069 - val_r2_score: 0.3526 - val_root_mean_squared_error: 6.8634
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.2618 - r2_score: 0.3908 - root_mean_squared_error: 6.5000 - val_loss: 48.2869 - val_r2_score: 0.3344 - val_root_mean_squared_error: 6.9489
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.9610 - r2_score: 0.3929 - root_mean_squared_error: 6.6291 - val_loss: 47.0408 - val_r2_score: 0.3533 - val_root_mean_squared_error: 6.8586
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.8051 - r2_score: 0.3369 - root_mean_squared_error: 6.8327 - val_loss: 46.7149 - val_r2_score: 0.3585 - val_root_mean_squared_error: 6.8348
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.9163 - r2_score: 0.3483 - root_mean_squared_error: 6.4732 - val_loss: 46.6073 - val_r2_score: 0.3607 - val_root_mean_squared_error: 6.8270
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.2054 - r2_score: 0.3630 - root_mean_squared_error: 6.5713 - val_loss: 51.1025 - val_r2_score: 0.2907 - val_root_mean_squared_error: 7.1486
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8616 - r2_score: 0.3736 - root_mean_squared_error: 6.5459 - val_loss: 45.9835 - val_r2_score: 0.3683 - val_root_mean_squared_error: 6.7811
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.6044 - r2_score: 0.3734 - root_mean_squared_error: 6.7462 - val_loss: 47.4553 - val_r2_score: 0.3462 - val_root_mean_squared_error: 6.8888
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.6035 - r2_score: 0.3659 - root_mean_squared_error: 6.6763 - val_loss: 47.1578 - val_r2_score: 0.3502 - val_root_mean_squared_error: 6.8672
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.5845 - r2_score: 0.4223 - root_mean_squared_error: 6.4482 - val_loss: 45.6087 - val_r2_score: 0.3738 - val_root_mean_squared_error: 6.7534
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.3802 - r2_score: 0.3617 - root_mean_squared_error: 6.6602 - val_loss: 48.4042 - val_r2_score: 0.3308 - val_root_mean_squared_error: 6.9573
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.4911 - r2_score: 0.3479 - root_mean_squared_error: 6.7397 - val_loss: 46.9445 - val_r2_score: 0.3571 - val_root_mean_squared_error: 6.8516
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.6008 - r2_score: 0.3754 - root_mean_squared_error: 6.5265 - val_loss: 46.8158 - val_r2_score: 0.3570 - val_root_mean_squared_error: 6.8422
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.2601 - r2_score: 0.3318 - root_mean_squared_error: 6.7963 - val_loss: 48.9024 - val_r2_score: 0.3232 - val_root_mean_squared_error: 6.9930
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.1274 - r2_score: 0.4073 - root_mean_squared_error: 6.4859 - val_loss: 45.4794 - val_r2_score: 0.3755 - val_root_mean_squared_error: 6.7438
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9800 - r2_score: 0.4058 - root_mean_squared_error: 6.3995 - val_loss: 44.7537 - val_r2_score: 0.3868 - val_root_mean_squared_error: 6.6898
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.7462 - r2_score: 0.4513 - root_mean_squared_error: 6.1409 - val_loss: 45.4321 - val_r2_score: 0.3774 - val_root_mean_squared_error: 6.7403
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.7412 - r2_score: 0.3593 - root_mean_squared_error: 6.8172 - val_loss: 44.0104 - val_r2_score: 0.3966 - val_root_mean_squared_error: 6.6340
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.8462 - r2_score: 0.4148 - root_mean_squared_error: 6.2294 - val_loss: 45.2518 - val_r2_score: 0.3782 - val_root_mean_squared_error: 6.7269
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.2584 - r2_score: 0.4161 - root_mean_squared_error: 6.6345 - val_loss: 44.0384 - val_r2_score: 0.3964 - val_root_mean_squared_error: 6.6361
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.3001 - r2_score: 0.3823 - root_mean_squared_error: 6.4243 - val_loss: 46.0042 - val_r2_score: 0.3679 - val_root_mean_squared_error: 6.7826
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.0382 - r2_score: 0.3958 - root_mean_squared_error: 6.3234 - val_loss: 45.7340 - val_r2_score: 0.3714 - val_root_mean_squared_error: 6.7627
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.8190 - r2_score: 0.4013 - root_mean_squared_error: 6.3886 - val_loss: 43.8647 - val_r2_score: 0.3985 - val_root_mean_squared_error: 6.6230
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.6885 - r2_score: 0.4431 - root_mean_squared_error: 6.2183 - val_loss: 44.2147 - val_r2_score: 0.3935 - val_root_mean_squared_error: 6.6494
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.4191 - r2_score: 0.4385 - root_mean_squared_error: 6.1941 - val_loss: 44.0240 - val_r2_score: 0.3966 - val_root_mean_squared_error: 6.6351
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.3344 - r2_score: 0.4388 - root_mean_squared_error: 6.2698 - val_loss: 43.3567 - val_r2_score: 0.4058 - val_root_mean_squared_error: 6.5846
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 42.0590 - r2_score: 0.4125 - root_mean_squared_error: 6.4840 - val_loss: 43.2247 - val_r2_score: 0.4074 - val_root_mean_squared_error: 6.5746
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44.5332 - r2_score: 0.4207 - root_mean_squared_error: 6.6505 - val_loss: 43.3088 - val_r2_score: 0.4065 - val_root_mean_squared_error: 6.5809
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.6615 - r2_score: 0.3905 - root_mean_squared_error: 6.2895 - val_loss: 46.3563 - val_r2_score: 0.3647 - val_root_mean_squared_error: 6.8085
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8480 - r2_score: 0.4070 - root_mean_squared_error: 6.5428 - val_loss: 44.2551 - val_r2_score: 0.3934 - val_root_mean_squared_error: 6.6524
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.0796 - r2_score: 0.4307 - root_mean_squared_error: 6.3272 - val_loss: 44.1051 - val_r2_score: 0.3965 - val_root_mean_squared_error: 6.6412
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.1094 - r2_score: 0.4091 - root_mean_squared_error: 6.3310 - val_loss: 45.2787 - val_r2_score: 0.3787 - val_root_mean_squared_error: 6.7289

# %%
mse_test, rmse_test, RSquared = model.evaluate(X_test, y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 32.4389 - r2_score: 0.4485 - root_mean_squared_error: 5.6910

# %%
print(f"MSE {mse_test}")
print(f"RMSE {rmse_test}")
print(f"R2 {RSquared}")
# Out:
# MSE 35.50992202758789
# RMSE 5.959020137786865
# R2 0.43480661511421204

# %%
pd.DataFrame(history.history)[['root_mean_squared_error', 'val_root_mean_squared_error']].plot(
    figsize=(8, 5), grid=True, xlabel="Epoch",
    style=["r--", "b--."])
plt.show()

# %%
HIST = pd.DataFrame(history.history)
HIST2 = HIST[HIST["r2_score"] >= 0.01]
HIST2["r2_score"].plot(
    figsize=(8, 5), grid=True, xlabel="Epoch",
    style=["r--", "b--."])
plt.show()

# %%
team1list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team2list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

predict = {
    "Team1" : team1list,
    "Team2" : team2list
}
df_predict = pd.DataFrame(predict)
finalmerge = pd.merge(df_predict,team_df, left_on='Team1', right_on='Tm', how='left')
finalmerge = finalmerge.drop("Tm", axis='columns')
finalfinalmerge = pd.merge(finalmerge,team_df2, left_on='Team2', right_on='Tm', how='left')
finalpredict = finalfinalmerge.drop("Tm", axis='columns')
finalpredict = finalpredict.drop("Team1", axis='columns')
finalpredict = finalpredict.drop("Team2", axis='columns')
for x in finalpredict.columns:
    finalpredict[x] = finalpredict[x].astype(str).astype(float)
finalpredict["PPP"] = finalpredict["PF"]/finalpredict["Ply"]
finalpredict["PPPA"] = finalpredict["DPA"]/finalpredict["DPly"]
finalpredict["PPPD"] = finalpredict["PPP"] - finalpredict["PPPA"]
finalpredict["T2PPP"] = finalpredict["T2PF"]/finalpredict["T2Ply"]
finalpredict["T2PPPA"] = finalpredict["T2DPA"]/finalpredict["T2DPly"]
finalpredict["T2PPPD"] = finalpredict["T2PPP"] - finalpredict["T2PPPA"]
numgames = 17 #Num of games so far in season
finalpredict["YdsT1"] = (finalpredict["Y/P"] * finalpredict["Ply"]) / numgames
finalpredict["YdsT2T2"] = (finalpredict["T2Y/P"] * finalpredict["T2Ply"]) / numgames
column_to_move = finalpredict.pop('YdsT1')
finalpredict.insert(0, 'YdsT1', column_to_move) 
column_to_move = finalpredict.pop('YdsT2T2')
finalpredict.insert(1, 'YdsT2T2', column_to_move) 
firstg_pred = model.predict(finalpredict)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
team2list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team1list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

predict = {
    "Team1" : team1list,
    "Team2" : team2list
}
df_predict = pd.DataFrame(predict)
finalmerge = pd.merge(df_predict,team_df, left_on='Team1', right_on='Tm', how='left')
finalmerge = finalmerge.drop("Tm", axis='columns')
finalfinalmerge = pd.merge(finalmerge,team_df2, left_on='Team2', right_on='Tm', how='left')
finalpredict = finalfinalmerge.drop("Tm", axis='columns')
finalpredict = finalpredict.drop("Team1", axis='columns')
finalpredict = finalpredict.drop("Team2", axis='columns')
for x in finalpredict.columns:
    finalpredict[x] = finalpredict[x].astype(str).astype(float)
finalpredict["PPP"] = finalpredict["PF"]/finalpredict["Ply"]
finalpredict["PPPA"] = finalpredict["DPA"]/finalpredict["DPly"]
finalpredict["PPPD"] = finalpredict["PPP"] - finalpredict["PPPA"]
finalpredict["T2PPP"] = finalpredict["T2PF"]/finalpredict["T2Ply"]
finalpredict["T2PPPA"] = finalpredict["T2DPA"]/finalpredict["T2DPly"]
finalpredict["T2PPPD"] = finalpredict["T2PPP"] - finalpredict["T2PPPA"]
numgames = 17 #Num of games so far in season
finalpredict["YdsT1"] = (finalpredict["Y/P"] * finalpredict["Ply"]) / numgames
finalpredict["YdsT2T2"] = (finalpredict["T2Y/P"] * finalpredict["T2Ply"]) / numgames
column_to_move = finalpredict.pop('YdsT1')
finalpredict.insert(0, 'YdsT1', column_to_move) 
column_to_move = finalpredict.pop('YdsT2T2')
finalpredict.insert(1, 'YdsT2T2', column_to_move) 
secondg_pred = model.predict(finalpredict)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
finalpredictlist = []
for x in range(len(firstg_pred)):
    first = firstg_pred[x]
    second = secondg_pred[x]
    team1dif = (first[0] + second[1])/2
    team2dif = (first[1] + second[0])/2
    finalpredictlist.append([team1dif,team2dif])

# %%
team1list = ["Buffalo Bills", 'Las Vegas Raiders','Los Angeles Chargers','New Orleans Saints','Tampa Bay Buccaneers','Indianapolis Colts','Cleveland Browns','San Francisco 49ers','Seattle Seahawks','New York Jets'
               ,'New York Giants','Los Angeles Rams','Pittsburgh Steelers','Cincinnati Bengals','Chicago Bears','Atlanta Falcons']
team2list = ["Miami Dolphins",'Baltimore Ravens','Carolina Panthers','Dallas Cowboys','Detroit Lions','Green Bay Packers','Jacksonville Jaguars','Minnesota Vikings','New England Patriots','Tennessee Titans'
               ,'Washington Commanders','Arizona Cardinals','Denver Broncos','Kansas City Chiefs','Houston Texans','Philadelphia Eagles']

# %%
gamenum = 0
for x in finalpredictlist:
    print(f"Team1: {team1list[gamenum]} Team2: {team2list[gamenum]}")
    print(f"{x[0]} , {x[1]}")
    print(x[0] - x[1])
    print(x[0] + x[1])
    print("--------------------------")
    gamenum = gamenum + 1
# Out:
# Team1: Buffalo Bills Team2: Miami Dolphins
# 25.339374542236328 , 22.08987808227539
# 3.2494964599609375
# 47.42925262451172
# --------------------------
# Team1: Las Vegas Raiders Team2: Baltimore Ravens
# 21.86417007446289 , 28.88444709777832
# -7.02027702331543
# 50.74861717224121
# --------------------------
# Team1: Los Angeles Chargers Team2: Carolina Panthers
# 24.06570053100586 , 19.74439811706543
# 4.32130241394043
# 43.81009864807129
# --------------------------
# Team1: New Orleans Saints Team2: Dallas Cowboys
# 22.598310470581055 , 21.39395523071289
# 1.204355239868164
# 43.992265701293945
# --------------------------
# Team1: Tampa Bay Buccaneers Team2: Detroit Lions
# 29.475072860717773 , 31.451751708984375
# -1.9766788482666016
# 60.92682456970215
# --------------------------
# Team1: Indianapolis Colts Team2: Green Bay Packers
# 23.662803649902344 , 27.282562255859375
# -3.6197586059570312
# 50.94536590576172
# --------------------------
# Team1: Cleveland Browns Team2: Jacksonville Jaguars
# 17.70832061767578 , 19.656558990478516
# -1.9482383728027344
# 37.3648796081543
# --------------------------
# Team1: San Francisco 49ers Team2: Minnesota Vikings
# 24.923860549926758 , 26.979684829711914
# -2.0558242797851562
# 51.90354537963867
# --------------------------
# Team1: Seattle Seahawks Team2: New England Patriots
# 21.920604705810547 , 18.561325073242188
# 3.3592796325683594
# 40.481929779052734
# --------------------------
# Team1: New York Jets Team2: Tennessee Titans
# 22.21002769470215 , 20.398723602294922
# 1.8113040924072266
# 42.60875129699707
# --------------------------
# Team1: New York Giants Team2: Washington Commanders
# 19.170368194580078 , 25.099933624267578
# -5.9295654296875
# 44.270301818847656
# --------------------------
# Team1: Los Angeles Rams Team2: Arizona Cardinals
# 23.45517349243164 , 24.67043685913086
# -1.2152633666992188
# 48.1256103515625
# --------------------------
# Team1: Pittsburgh Steelers Team2: Denver Broncos
# 19.117700576782227 , 21.58484649658203
# -2.4671459197998047
# 40.70254707336426
# --------------------------
# Team1: Cincinnati Bengals Team2: Kansas City Chiefs
# 23.6361083984375 , 23.19072723388672
# 0.44538116455078125
# 46.82683563232422
# --------------------------
# Team1: Chicago Bears Team2: Houston Texans
# 17.82417869567871 , 19.274444580078125
# -1.450265884399414
# 37.098623275756836
# --------------------------
# Team1: Atlanta Falcons Team2: Philadelphia Eagles
# 23.369983673095703 , 26.772998809814453
# -3.40301513671875
# 50.142982482910156
# --------------------------

# %%
gamenum = 0
for x in finalpredictlist:
    print(f"Team1: {team1list[gamenum]} Team2: {team2list[gamenum]}")
    print(x[0] - x[1])
    gamenum = gamenum + 1
# Out:
# Team1: Buffalo Bills Team2: Miami Dolphins
# 3.2494964599609375
# Team1: Las Vegas Raiders Team2: Baltimore Ravens
# -7.02027702331543
# Team1: Los Angeles Chargers Team2: Carolina Panthers
# 4.32130241394043
# Team1: New Orleans Saints Team2: Dallas Cowboys
# 1.204355239868164
# Team1: Tampa Bay Buccaneers Team2: Detroit Lions
# -1.9766788482666016
# Team1: Indianapolis Colts Team2: Green Bay Packers
# -3.6197586059570312
# Team1: Cleveland Browns Team2: Jacksonville Jaguars
# -1.9482383728027344
# Team1: San Francisco 49ers Team2: Minnesota Vikings
# -2.0558242797851562
# Team1: Seattle Seahawks Team2: New England Patriots
# 3.3592796325683594
# Team1: New York Jets Team2: Tennessee Titans
# 1.8113040924072266
# Team1: New York Giants Team2: Washington Commanders
# -5.9295654296875
# Team1: Los Angeles Rams Team2: Arizona Cardinals
# -1.2152633666992188
# Team1: Pittsburgh Steelers Team2: Denver Broncos
# -2.4671459197998047
# Team1: Cincinnati Bengals Team2: Kansas City Chiefs
# 0.44538116455078125
# Team1: Chicago Bears Team2: Houston Texans
# -1.450265884399414
# Team1: Atlanta Falcons Team2: Philadelphia Eagles
# -3.40301513671875

# %%
gamenum = 0
for x in finalpredictlist:
    print(f"Team1: {team1list[gamenum]} Team2: {team2list[gamenum]}")
    print(x[0] + x[1])
    gamenum = gamenum + 1
# Out:
# Team1: Buffalo Bills Team2: Miami Dolphins
# 47.42925262451172
# Team1: Las Vegas Raiders Team2: Baltimore Ravens
# 50.74861717224121
# Team1: Los Angeles Chargers Team2: Carolina Panthers
# 43.81009864807129
# Team1: New Orleans Saints Team2: Dallas Cowboys
# 43.992265701293945
# Team1: Tampa Bay Buccaneers Team2: Detroit Lions
# 60.92682456970215
# Team1: Indianapolis Colts Team2: Green Bay Packers
# 50.94536590576172
# Team1: Cleveland Browns Team2: Jacksonville Jaguars
# 37.3648796081543
# Team1: San Francisco 49ers Team2: Minnesota Vikings
# 51.90354537963867
# Team1: Seattle Seahawks Team2: New England Patriots
# 40.481929779052734
# Team1: New York Jets Team2: Tennessee Titans
# 42.60875129699707
# Team1: New York Giants Team2: Washington Commanders
# 44.270301818847656
# Team1: Los Angeles Rams Team2: Arizona Cardinals
# 48.1256103515625
# Team1: Pittsburgh Steelers Team2: Denver Broncos
# 40.70254707336426
# Team1: Cincinnati Bengals Team2: Kansas City Chiefs
# 46.82683563232422
# Team1: Chicago Bears Team2: Houston Texans
# 37.098623275756836
# Team1: Atlanta Falcons Team2: Philadelphia Eagles
# 50.142982482910156
